# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification

genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

if not os.path.exists('content'):
  os.makedirs('content/')
  os.makedirs('content/spectrograms30sec')
  os.makedirs('content/spectrograms30sec/train')
  os.makedirs('content/spectrograms30sec/test')

  for g in genres:
    path_audio = os.path.join('content/audio3sec',f'{g}')
    os.makedirs(path_audio)
    path_train = os.path.join('content/spectrograms30sec/train',f'{g}')
    path_test = os.path.join('content/spectrograms30sec/test',f'{g}')
    os.makedirs(path_train)
    os.makedirs(path_test)

# %%
for g in genres:
  if len(os.path.join('content/spectrograms30sec/train/',f"{g}")) == 0:
    j = 0
    print(g)
    for filename in os.listdir(os.path.join('content/audio3sec',f"{g}")):
      song  =  os.path.join(f'content/audio3sec/{g}',f'{filename}')
      j = j+1
      
      y,sr = librosa.load(song,duration=3)
      #print(sr)
      mels = librosa.feature.melspectrogram(y=y,sr=sr)
      fig = plt.Figure()
      canvas = FigureCanvas(fig)
      p = plt.imshow(librosa.power_to_db(mels,ref=np.max))
      plt.savefig(f'content/spectrograms30sec/train/{g}/{g+str(j)}.png')

# %%
directory = "content/spectrograms30sec/train/"
for g in genres:
  if len(os.listdir(os.path.join('content/spectrograms30sec/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:10]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,"content/spectrograms30sec/test/" + f"{g}")

# %%
train_dir = "content/spectrograms30sec/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(288,432),color_mode="rgba",class_mode='categorical',batch_size=128)

validation_dir = "content/spectrograms30sec/test/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(288,432),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 900 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
def GenreModel(input_shape = (288,432,4),classes=10):
  np.random.seed(10)
  X_input = Input(input_shape)

  X = Conv2D(8,kernel_size=(3,3),strides=(1,1),kernel_initializer = glorot_uniform(seed=10))(X_input)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(16,kernel_size=(3,3),strides = (1,1),kernel_initializer=glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(32,kernel_size=(3,3),strides = (1,1),kernel_initializer = glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  X = Conv2D(64,kernel_size=(3,3),strides=(1,1),kernel_initializer=glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=-1)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  
  X = Flatten()(X)

  X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=10))(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# checkpoint_path = "saved_cnn3/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=False,
#                                                 verbose=1)

model = GenreModel(input_shape=(288,432,4), classes=10)
opt = Adam(learning_rate=0.00005)
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy',get_f1])
# Out:
# 2022-11-16 08:20:01.108313: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 08:20:01.108977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.109097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.109188: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.430807: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.430935: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.431030: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 08:20:01.431118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21604 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 288, 432, 4)]     0
#
#  conv2d (Conv2D)             (None, 286, 430, 8)       296
#
#  batch_normalization (BatchN  (None, 286, 430, 8)      32
#  ormalization)
#
#  activation (Activation)     (None, 286, 430, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 143, 215, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 141, 213, 16)      1168
#
#  batch_normalization_1 (Batc  (None, 141, 213, 16)     64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 141, 213, 16)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 106, 16)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 68, 104, 32)       4640
#
#  batch_normalization_2 (Batc  (None, 68, 104, 32)      128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 68, 104, 32)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 34, 52, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 50, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 32, 50, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 50, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  fc10 (Dense)                (None, 10)                256010
#
# =================================================================
# Total params: 281,090
# Trainable params: 280,850
# Non-trainable params: 240
# _________________________________________________________________

# %%
if os.path.exists("saved/saved_cnn30_3"):
    model_history = model.load_model("saved/saved_cnn30_3")
else:
    model_history = model.fit_generator(train_generator,epochs=50,validation_data=vali_generator)
    model.save("saved/saved_cnn30_3")
# Out:
# /tmp/ipykernel_69495/1519023632.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=50,validation_data=vali_generator)
# Epoch 1/50
# 2022-11-16 08:20:12.515792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# 2022-11-16 08:20:13.801411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 8/8 [==============================] - 7s 501ms/step - loss: 2.7494 - accuracy: 0.1133 - get_f1: 0.0199 - val_loss: 2.3012 - val_accuracy: 0.1700 - val_get_f1: 0.0000e+00
# Epoch 2/50
# 8/8 [==============================] - 3s 412ms/step - loss: 2.4041 - accuracy: 0.2078 - get_f1: 0.0316 - val_loss: 2.2984 - val_accuracy: 0.1800 - val_get_f1: 0.0000e+00
# Epoch 3/50
# 8/8 [==============================] - 3s 411ms/step - loss: 2.1070 - accuracy: 0.2478 - get_f1: 0.0999 - val_loss: 2.2956 - val_accuracy: 0.1100 - val_get_f1: 0.0000e+00
# Epoch 4/50
# 8/8 [==============================] - 3s 425ms/step - loss: 1.9687 - accuracy: 0.3156 - get_f1: 0.1337 - val_loss: 2.2921 - val_accuracy: 0.1500 - val_get_f1: 0.0000e+00
# Epoch 5/50
# 8/8 [==============================] - 3s 419ms/step - loss: 1.8321 - accuracy: 0.3356 - get_f1: 0.1833 - val_loss: 2.2880 - val_accuracy: 0.1700 - val_get_f1: 0.0000e+00
# Epoch 6/50
# 8/8 [==============================] - 3s 468ms/step - loss: 1.7363 - accuracy: 0.3611 - get_f1: 0.2011 - val_loss: 2.2899 - val_accuracy: 0.1200 - val_get_f1: 0.0000e+00
# Epoch 7/50
# 8/8 [==============================] - 3s 402ms/step - loss: 1.6483 - accuracy: 0.4100 - get_f1: 0.2398 - val_loss: 2.2909 - val_accuracy: 0.2000 - val_get_f1: 0.0000e+00
# Epoch 8/50
# 8/8 [==============================] - 3s 402ms/step - loss: 1.5835 - accuracy: 0.4256 - get_f1: 0.2348 - val_loss: 2.2849 - val_accuracy: 0.2000 - val_get_f1: 0.0000e+00
# Epoch 9/50
# 8/8 [==============================] - 3s 415ms/step - loss: 1.5203 - accuracy: 0.4622 - get_f1: 0.2233 - val_loss: 2.3025 - val_accuracy: 0.1800 - val_get_f1: 0.0000e+00
# Epoch 10/50
# 8/8 [==============================] - 3s 405ms/step - loss: 1.4479 - accuracy: 0.4956 - get_f1: 0.2964 - val_loss: 2.2940 - val_accuracy: 0.1900 - val_get_f1: 0.0000e+00
# Epoch 11/50
# 8/8 [==============================] - 3s 415ms/step - loss: 1.4630 - accuracy: 0.4711 - get_f1: 0.3205 - val_loss: 2.3003 - val_accuracy: 0.2000 - val_get_f1: 0.0000e+00
# Epoch 12/50
# 8/8 [==============================] - 3s 409ms/step - loss: 1.3533 - accuracy: 0.5356 - get_f1: 0.3554 - val_loss: 2.3262 - val_accuracy: 0.2000 - val_get_f1: 0.0000e+00
# Epoch 13/50
# 8/8 [==============================] - 3s 411ms/step - loss: 1.3145 - accuracy: 0.5600 - get_f1: 0.3993 - val_loss: 2.3515 - val_accuracy: 0.2000 - val_get_f1: 0.0000e+00
# Epoch 14/50
# 8/8 [==============================] - 3s 406ms/step - loss: 1.2340 - accuracy: 0.5944 - get_f1: 0.4361 - val_loss: 2.3480 - val_accuracy: 0.1700 - val_get_f1: 0.0000e+00
# Epoch 15/50
# 8/8 [==============================] - 3s 413ms/step - loss: 1.1940 - accuracy: 0.6067 - get_f1: 0.4300 - val_loss: 2.3948 - val_accuracy: 0.1900 - val_get_f1: 0.0000e+00
# Epoch 16/50
# 8/8 [==============================] - 3s 404ms/step - loss: 1.1619 - accuracy: 0.6211 - get_f1: 0.4840 - val_loss: 2.3987 - val_accuracy: 0.1300 - val_get_f1: 0.0000e+00
# Epoch 17/50
# 8/8 [==============================] - 3s 412ms/step - loss: 1.1088 - accuracy: 0.6644 - get_f1: 0.5100 - val_loss: 2.4358 - val_accuracy: 0.1700 - val_get_f1: 0.0000e+00
# Epoch 18/50
# 8/8 [==============================] - 3s 415ms/step - loss: 1.0860 - accuracy: 0.6344 - get_f1: 0.4490 - val_loss: 2.4746 - val_accuracy: 0.1800 - val_get_f1: 0.0198
# Epoch 19/50
# 8/8 [==============================] - 3s 404ms/step - loss: 1.0206 - accuracy: 0.6944 - get_f1: 0.5717 - val_loss: 2.5930 - val_accuracy: 0.1700 - val_get_f1: 0.1429
# Epoch 20/50
# 8/8 [==============================] - 3s 395ms/step - loss: 1.0206 - accuracy: 0.6822 - get_f1: 0.5730 - val_loss: 2.6097 - val_accuracy: 0.1500 - val_get_f1: 0.1429
# Epoch 21/50
# 8/8 [==============================] - 3s 467ms/step - loss: 1.0288 - accuracy: 0.6678 - get_f1: 0.5298 - val_loss: 2.5623 - val_accuracy: 0.1700 - val_get_f1: 0.1404
# Epoch 22/50
# 8/8 [==============================] - 3s 471ms/step - loss: 0.9970 - accuracy: 0.6811 - get_f1: 0.6160 - val_loss: 2.6821 - val_accuracy: 0.1900 - val_get_f1: 0.1639
# Epoch 23/50
# 8/8 [==============================] - 3s 463ms/step - loss: 0.9076 - accuracy: 0.7122 - get_f1: 0.5534 - val_loss: 2.7000 - val_accuracy: 0.1900 - val_get_f1: 0.1653
# Epoch 24/50
# 8/8 [==============================] - 3s 409ms/step - loss: 0.8667 - accuracy: 0.7544 - get_f1: 0.6026 - val_loss: 2.8175 - val_accuracy: 0.1900 - val_get_f1: 0.1515
# Epoch 25/50
# 8/8 [==============================] - 3s 403ms/step - loss: 0.8255 - accuracy: 0.7711 - get_f1: 0.6687 - val_loss: 2.8029 - val_accuracy: 0.1900 - val_get_f1: 0.2158
# Epoch 26/50
# 8/8 [==============================] - 3s 468ms/step - loss: 0.8091 - accuracy: 0.7733 - get_f1: 0.6516 - val_loss: 2.8923 - val_accuracy: 0.1900 - val_get_f1: 0.1931
# Epoch 27/50
# 8/8 [==============================] - 3s 418ms/step - loss: 0.7855 - accuracy: 0.7911 - get_f1: 0.6851 - val_loss: 2.9450 - val_accuracy: 0.1900 - val_get_f1: 0.1935
# Epoch 28/50
# 8/8 [==============================] - 3s 409ms/step - loss: 0.7633 - accuracy: 0.8033 - get_f1: 0.6693 - val_loss: 3.0343 - val_accuracy: 0.1900 - val_get_f1: 0.2452
# Epoch 29/50
# 8/8 [==============================] - 3s 480ms/step - loss: 0.7169 - accuracy: 0.8122 - get_f1: 0.6965 - val_loss: 3.1835 - val_accuracy: 0.1900 - val_get_f1: 0.1724
# Epoch 30/50
# 8/8 [==============================] - 3s 420ms/step - loss: 0.6905 - accuracy: 0.8211 - get_f1: 0.7449 - val_loss: 3.1164 - val_accuracy: 0.1900 - val_get_f1: 0.2249
# Epoch 31/50
# 8/8 [==============================] - 3s 417ms/step - loss: 0.6693 - accuracy: 0.8422 - get_f1: 0.7749 - val_loss: 3.2897 - val_accuracy: 0.1900 - val_get_f1: 0.2262
# Epoch 32/50
# 8/8 [==============================] - 3s 398ms/step - loss: 0.6375 - accuracy: 0.8567 - get_f1: 0.7358 - val_loss: 3.2443 - val_accuracy: 0.1900 - val_get_f1: 0.2123
# Epoch 33/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.6876 - accuracy: 0.8189 - get_f1: 0.7542 - val_loss: 3.6858 - val_accuracy: 0.1900 - val_get_f1: 0.1905
# Epoch 34/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.6320 - accuracy: 0.8544 - get_f1: 0.7973 - val_loss: 3.0901 - val_accuracy: 0.1900 - val_get_f1: 0.2289
# Epoch 35/50
# 8/8 [==============================] - 3s 406ms/step - loss: 0.5870 - accuracy: 0.8722 - get_f1: 0.8185 - val_loss: 3.0752 - val_accuracy: 0.1900 - val_get_f1: 0.2303
# Epoch 36/50
# 8/8 [==============================] - 3s 462ms/step - loss: 0.5714 - accuracy: 0.8578 - get_f1: 0.8313 - val_loss: 3.3752 - val_accuracy: 0.1900 - val_get_f1: 0.2021
# Epoch 37/50
# 8/8 [==============================] - 3s 415ms/step - loss: 0.5642 - accuracy: 0.8833 - get_f1: 0.8217 - val_loss: 3.2541 - val_accuracy: 0.1900 - val_get_f1: 0.2171
# Epoch 38/50
# 8/8 [==============================] - 3s 407ms/step - loss: 0.5200 - accuracy: 0.8944 - get_f1: 0.8463 - val_loss: 3.0675 - val_accuracy: 0.1900 - val_get_f1: 0.2317
# Epoch 39/50
# 8/8 [==============================] - 3s 407ms/step - loss: 0.5182 - accuracy: 0.8811 - get_f1: 0.8361 - val_loss: 3.5075 - val_accuracy: 0.1900 - val_get_f1: 0.2032
# Epoch 40/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.5701 - accuracy: 0.8533 - get_f1: 0.7999 - val_loss: 3.2230 - val_accuracy: 0.1900 - val_get_f1: 0.2209
# Epoch 41/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.4894 - accuracy: 0.8978 - get_f1: 0.8294 - val_loss: 3.1225 - val_accuracy: 0.1900 - val_get_f1: 0.2222
# Epoch 42/50
# 8/8 [==============================] - 3s 414ms/step - loss: 0.4689 - accuracy: 0.9078 - get_f1: 0.8612 - val_loss: 2.9931 - val_accuracy: 0.2300 - val_get_f1: 0.2381
# Epoch 43/50
# 8/8 [==============================] - 3s 415ms/step - loss: 0.4597 - accuracy: 0.9089 - get_f1: 0.8568 - val_loss: 2.7427 - val_accuracy: 0.2500 - val_get_f1: 0.2548
# Epoch 44/50
# 8/8 [==============================] - 3s 413ms/step - loss: 0.4352 - accuracy: 0.9256 - get_f1: 0.9053 - val_loss: 2.6847 - val_accuracy: 0.2400 - val_get_f1: 0.2410
# Epoch 45/50
# 8/8 [==============================] - 3s 404ms/step - loss: 0.4141 - accuracy: 0.9411 - get_f1: 0.8659 - val_loss: 2.6806 - val_accuracy: 0.2500 - val_get_f1: 0.2561
# Epoch 46/50
# 8/8 [==============================] - 3s 412ms/step - loss: 0.4511 - accuracy: 0.9078 - get_f1: 0.8954 - val_loss: 2.4856 - val_accuracy: 0.2800 - val_get_f1: 0.2545
# Epoch 47/50
# 8/8 [==============================] - 3s 408ms/step - loss: 0.3846 - accuracy: 0.9500 - get_f1: 0.9203 - val_loss: 2.5079 - val_accuracy: 0.2900 - val_get_f1: 0.2821
# Epoch 48/50
# 8/8 [==============================] - 3s 405ms/step - loss: 0.3608 - accuracy: 0.9556 - get_f1: 0.9325 - val_loss: 2.3117 - val_accuracy: 0.3000 - val_get_f1: 0.3038
# Epoch 49/50
# 8/8 [==============================] - 3s 467ms/step - loss: 0.3584 - accuracy: 0.9511 - get_f1: 0.9314 - val_loss: 2.1301 - val_accuracy: 0.3300 - val_get_f1: 0.3057
# Epoch 50/50
# 8/8 [==============================] - 3s 416ms/step - loss: 0.3442 - accuracy: 0.9611 - get_f1: 0.9394 - val_loss: 2.0995 - val_accuracy: 0.3400 - val_get_f1: 0.3185
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved/saved_cnn30_3/assets
# INFO:tensorflow:Assets written to: saved/saved_cnn30_3/assets

# %%
metrics = model_history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
test_loss, test_acc, _ = model.evaluate(vali_generator, batch_size=128)
print("The test Loss is :", test_loss)
print("\nThe Best test Accuracy is :", test_acc*100)
# Out:
# 1/1 [==============================] - 0s 365ms/step - loss: 2.0995 - accuracy: 0.3400 - get_f1: 0.3185
# The test Loss is : 2.0995285511016846
#
# The Best test Accuracy is : 34.00000035762787

# %%
class estimator:
  _estimator_type = ''
  classes_=[]
  def __init__(self, model, classes):
    self.model = model
    self._estimator_type = 'classifier'
    self.classes_ = classes
  def predict(self, X):
    y_prob= self.model.predict(X)
    y_pred = y_prob.argmax(axis=1)
    return y_pred

classifier = estimator(model, genres)
figsize = (12,12)

x, y = zip(*(vali_generator[i] for i in range(len(vali_generator))))
x_val, y_val = np.vstack(x), np.vstack(y)
y_val = np.argmax(y_val, axis=1)

# %%
ConfusionMatrixDisplay.from_estimator(classifier, x_val, y_val, cmap='Blues', display_labels=genres ,normalize='true', ax=plt.subplots(figsize=figsize)[1])
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %%
import pathlib
input_dir = pathlib.Path("input/")
audio_file_name = "chopin.wav"
sample_dir = "input/samples/"
audio_seg_dir = "input/audio_segments/"

predictions = []

if not input_dir.exists():
    os.mkdir("input")
    os.mkdir(sample_dir)
    os.mkdir(audio_seg_dir)

sample, sample_sr = librosa.load(os.path.join(sample_dir, audio_file_name))
sample_duration = int(librosa.get_duration(y=sample, sr=sample_sr))
Audio(sample, rate=sample_sr)

for i in range(int(sample_duration/3)): 
    t1 = i * 3 * 1000 #Works in milliseconds
    t2 = (i+1) * 3 * 1000
    newAudio = AudioSegment.from_wav(os.path.join(sample_dir, audio_file_name))
    newAudio = newAudio[t1:t2]
    newAudio.export(audio_seg_dir + 'audio_seg_' + str(i) +'.wav', format="wav") #Exports to a wav file in the current path.

from keras.utils import load_img, img_to_array

for af in os.listdir(audio_seg_dir):
    audio, sr = librosa.load(os.path.join(audio_seg_dir, af))
    mels = librosa.feature.melspectrogram(y=audio,sr=sr)
    fig = plt.Figure()
    canvas = FigureCanvas(fig)
    p = plt.imshow(librosa.power_to_db(mels,ref=np.max))

    spec_dir = "input/specs_segments"

    if not os.path.exists(spec_dir):
        os.mkdir(spec_dir)

    plt.savefig(os.path.join(spec_dir, af[:-3] + 'png'))

    image_data = load_img(os.path.join(spec_dir, af[:-3] + 'png'),color_mode='rgba',target_size=(288,432))
    image = img_to_array(image_data)
    image = np.reshape(image,(1,288,432,4))

    p = model.predict(image/255)
    p = p.reshape((10,))

    predictions.append(p)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
avg_preds = [x / len(predictions) for x in np.array(predictions).sum(axis=0)]
predicted_label = np.argmax(avg_preds)

print("The Predicted Label was: " + genres[predicted_label])
# Out:
# The Predicted Label was: jazz

# %%
plt.figure(figsize=(30,10))
plt.bar(genres, np.array(avg_preds))
plt.title("Inference Results")
plt.show()
