# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2022-11-19 21:23:01.231377: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-19 21:23:02.892628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:02.908454: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:02.908593: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification

genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

if not os.path.exists('content'):
  os.makedirs('content/')
  os.makedirs('content/spectrograms3sec_old')
  os.makedirs('content/spectrograms3sec_old/train')
  os.makedirs('content/spectrograms3sec_old/test')

  for g in genres:
    path_audio = os.path.join('content/audio3sec',f'{g}')
    os.makedirs(path_audio)
    path_train = os.path.join('content/spectrograms3sec_old/train',f'{g}')
    path_test = os.path.join('content/spectrograms3sec_old/test',f'{g}')
    os.makedirs(path_train)
    os.makedirs(path_test)

# %%
from pydub import AudioSegment
i = 0
for g in genres:
  if len(os.listdir(os.path.join('content/audio3sec/',f"{g}"))) == 0:
    j=0
    print(f"{g}")
    for filename in os.listdir(os.path.join('data/genres',f"{g}")):
      song  =  os.path.join(f'data/genres/{g}',f'{filename}')
      j = j+1
      for w in range(0,10):
        i = i+1
        #print(i)
        t1 = 3*(w)*1000
        t2 = 3*(w+1)*1000
        newAudio = AudioSegment.from_wav(song)
        new = newAudio[t1:t2]
        new.export(f'content/audio3sec/{g}/{g+str(j)+str(w)}.wav', format="wav")

# %%
for g in genres:
  if len(os.path.join('content/spectrograms3sec_old/train/',f"{g}")) == 0:
    j = 0
    print(g)
    for filename in os.listdir(os.path.join('content/audio3sec',f"{g}")):
      song  =  os.path.join(f'content/audio3sec/{g}',f'{filename}')
      j = j+1
      
      y,sr = librosa.load(song,duration=3)
      #print(sr)
      mels = librosa.feature.melspectrogram(y=y,sr=sr)
      fig = plt.Figure()
      canvas = FigureCanvas(fig)
      p = plt.imshow(librosa.power_to_db(mels,ref=np.max))
      plt.savefig(f'content/spectrograms3sec_old/train/{g}/{g+str(j)}.png')

# %%
directory = "content/spectrograms3sec_old/train/"
for g in genres:
  if len(os.listdir(os.path.join('content/spectrograms3sec_old/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:200]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,"content/spectrograms3sec_old/test/" + f"{g}")

# %%
train_dir = "content/spectrograms3sec_old/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(288,432),color_mode="rgba",class_mode='categorical',batch_size=128)

validation_dir = "content/spectrograms3sec_old/test/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(288,432),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 8000 images belonging to 10 classes.
# Found 2000 images belonging to 10 classes.

# %%
def GenreModel(input_shape = (288,432,4),classes=10):
  
  X_input = Input(input_shape)
  n_filters = 64

  X = layers.Conv2D(n_filters, (3,3), activation='relu')(X_input)
  X = layers.MaxPooling2D((2,2))(X)
  X = layers.Dropout(0.2)(X)

  X = layers.Conv2D(n_filters, (3,3), activation='relu')(X)
  X = layers.MaxPooling2D((2,2))(X)
  X = layers.Dropout(0.2)(X)

  X = layers.Conv2D(n_filters, (3,3), activation='relu')(X)
  X = layers.MaxPooling2D((2,2))(X)
  X = layers.Dropout(0.2)(X)

  # Added an extra layer
  X = layers.Conv2D(n_filters, (3,3), activation='relu')(X)
  X = layers.MaxPooling2D((2,2))(X)
  X = layers.Dropout(0.3)(X)

  X = layers.Flatten()(X)
  X = layers.Dense(10, activation='softmax')(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# checkpoint_path = "saved_cnn2/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=True,
#                                                 verbose=1)

model = GenreModel(input_shape=(288,432,4), classes=10)
opt = Adam(learning_rate=0.0005)
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy',get_f1])
# Out:
# 2022-11-19 21:23:03.214919: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-19 21:23:03.215699: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.215839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.215934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.532174: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.532296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.532391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-19 21:23:03.532470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11616 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 288, 432, 4)]     0
#
#  conv2d (Conv2D)             (None, 286, 430, 64)      2368
#
#  max_pooling2d (MaxPooling2D  (None, 143, 215, 64)     0
#  )
#
#  dropout (Dropout)           (None, 143, 215, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 141, 213, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 106, 64)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 70, 106, 64)       0
#
#  conv2d_2 (Conv2D)           (None, 68, 104, 64)       36928
#
#  max_pooling2d_2 (MaxPooling  (None, 34, 52, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 34, 52, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 50, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 25, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 25, 64)        0
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense (Dense)               (None, 10)                256010
#
# =================================================================
# Total params: 369,162
# Trainable params: 369,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
if os.path.exists("saved/saved_cnn11_3"):
    model_history = model.load_model("saved/saved_cnn11_3")
else:
    model_history = model.fit_generator(train_generator,epochs=70,validation_data=vali_generator)
    model.save("saved/saved_cnn11_3")
# Out:
# /tmp/ipykernel_709201/1912687838.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=70,validation_data=vali_generator)
# Epoch 1/70
# 2022-11-19 21:23:04.932801: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inGenreModel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2022-11-19 21:23:05.970626: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:05.970658: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2022-11-19 21:23:06.346170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# 2022-11-19 21:23:07.795986: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.87GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.222669: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-11-19 21:23:08.763643: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 976.78MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.763976: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.87GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.763991: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 977.10MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.763997: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.764001: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.850938: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:08.850966: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2022-11-19 21:23:09.012094: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 63/63 [==============================] - 75s 1s/step - loss: 2.1927 - accuracy: 0.1867 - get_f1: 0.0309 - val_loss: 1.9798 - val_accuracy: 0.2750 - val_get_f1: 0.0435
# Epoch 2/70
# 63/63 [==============================] - 70s 1s/step - loss: 1.6924 - accuracy: 0.3811 - get_f1: 0.2298 - val_loss: 1.7086 - val_accuracy: 0.3965 - val_get_f1: 0.1210
# Epoch 3/70
# 63/63 [==============================] - 70s 1s/step - loss: 1.4916 - accuracy: 0.4639 - get_f1: 0.3361 - val_loss: 1.5778 - val_accuracy: 0.4060 - val_get_f1: 0.2284
# Epoch 4/70
# 63/63 [==============================] - 70s 1s/step - loss: 1.3822 - accuracy: 0.5027 - get_f1: 0.4053 - val_loss: 1.4209 - val_accuracy: 0.5035 - val_get_f1: 0.3434
# Epoch 5/70
# 63/63 [==============================] - 69s 1s/step - loss: 1.3052 - accuracy: 0.5370 - get_f1: 0.4534 - val_loss: 1.3357 - val_accuracy: 0.5270 - val_get_f1: 0.3911
# Epoch 6/70
# 63/63 [==============================] - 70s 1s/step - loss: 1.1827 - accuracy: 0.5819 - get_f1: 0.5140 - val_loss: 1.1998 - val_accuracy: 0.5990 - val_get_f1: 0.4829
# Epoch 7/70
# 63/63 [==============================] - 70s 1s/step - loss: 1.0659 - accuracy: 0.6267 - get_f1: 0.5816 - val_loss: 1.1086 - val_accuracy: 0.6375 - val_get_f1: 0.5353
# Epoch 8/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.9689 - accuracy: 0.6597 - get_f1: 0.6332 - val_loss: 1.0981 - val_accuracy: 0.6210 - val_get_f1: 0.5590
# Epoch 9/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.8715 - accuracy: 0.6949 - get_f1: 0.6723 - val_loss: 0.9914 - val_accuracy: 0.6610 - val_get_f1: 0.6253
# Epoch 10/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.8045 - accuracy: 0.7256 - get_f1: 0.7076 - val_loss: 0.9812 - val_accuracy: 0.6655 - val_get_f1: 0.6376
# Epoch 11/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.7487 - accuracy: 0.7395 - get_f1: 0.7308 - val_loss: 0.9228 - val_accuracy: 0.6720 - val_get_f1: 0.6563
# Epoch 12/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.6704 - accuracy: 0.7681 - get_f1: 0.7628 - val_loss: 0.8630 - val_accuracy: 0.7135 - val_get_f1: 0.7011
# Epoch 13/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.6247 - accuracy: 0.7850 - get_f1: 0.7791 - val_loss: 0.8570 - val_accuracy: 0.7160 - val_get_f1: 0.7061
# Epoch 14/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.5617 - accuracy: 0.8008 - get_f1: 0.8017 - val_loss: 0.9065 - val_accuracy: 0.6990 - val_get_f1: 0.6968
# Epoch 15/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.5370 - accuracy: 0.8106 - get_f1: 0.8111 - val_loss: 0.8382 - val_accuracy: 0.7130 - val_get_f1: 0.7111
# Epoch 16/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.4989 - accuracy: 0.8254 - get_f1: 0.8236 - val_loss: 0.8681 - val_accuracy: 0.7015 - val_get_f1: 0.6922
# Epoch 17/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.4555 - accuracy: 0.8450 - get_f1: 0.8430 - val_loss: 0.8215 - val_accuracy: 0.7325 - val_get_f1: 0.7310
# Epoch 18/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.4110 - accuracy: 0.8540 - get_f1: 0.8554 - val_loss: 0.8202 - val_accuracy: 0.7350 - val_get_f1: 0.7388
# Epoch 19/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.3798 - accuracy: 0.8640 - get_f1: 0.8633 - val_loss: 0.7739 - val_accuracy: 0.7495 - val_get_f1: 0.7514
# Epoch 20/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.3400 - accuracy: 0.8780 - get_f1: 0.8780 - val_loss: 0.9104 - val_accuracy: 0.7300 - val_get_f1: 0.7312
# Epoch 21/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.3299 - accuracy: 0.8817 - get_f1: 0.8820 - val_loss: 0.7986 - val_accuracy: 0.7585 - val_get_f1: 0.7558
# Epoch 22/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.3039 - accuracy: 0.8917 - get_f1: 0.8927 - val_loss: 0.8009 - val_accuracy: 0.7555 - val_get_f1: 0.7614
# Epoch 23/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.2822 - accuracy: 0.9007 - get_f1: 0.8996 - val_loss: 0.8078 - val_accuracy: 0.7610 - val_get_f1: 0.7681
# Epoch 24/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.2611 - accuracy: 0.9071 - get_f1: 0.9063 - val_loss: 0.8812 - val_accuracy: 0.7525 - val_get_f1: 0.7561
# Epoch 25/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.2291 - accuracy: 0.9178 - get_f1: 0.9181 - val_loss: 0.8357 - val_accuracy: 0.7620 - val_get_f1: 0.7647
# Epoch 26/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.2248 - accuracy: 0.9215 - get_f1: 0.9209 - val_loss: 0.8036 - val_accuracy: 0.7760 - val_get_f1: 0.7740
# Epoch 27/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1883 - accuracy: 0.9345 - get_f1: 0.9361 - val_loss: 0.9303 - val_accuracy: 0.7490 - val_get_f1: 0.7495
# Epoch 28/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1774 - accuracy: 0.9356 - get_f1: 0.9365 - val_loss: 0.9591 - val_accuracy: 0.7655 - val_get_f1: 0.7706
# Epoch 29/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1860 - accuracy: 0.9321 - get_f1: 0.9312 - val_loss: 0.8820 - val_accuracy: 0.7680 - val_get_f1: 0.7687
# Epoch 30/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1808 - accuracy: 0.9369 - get_f1: 0.9369 - val_loss: 0.9053 - val_accuracy: 0.7650 - val_get_f1: 0.7718
# Epoch 31/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1454 - accuracy: 0.9495 - get_f1: 0.9493 - val_loss: 1.0193 - val_accuracy: 0.7525 - val_get_f1: 0.7562
# Epoch 32/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1379 - accuracy: 0.9507 - get_f1: 0.9501 - val_loss: 0.9891 - val_accuracy: 0.7640 - val_get_f1: 0.7685
# Epoch 33/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1496 - accuracy: 0.9451 - get_f1: 0.9448 - val_loss: 0.9188 - val_accuracy: 0.7620 - val_get_f1: 0.7640
# Epoch 34/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1319 - accuracy: 0.9550 - get_f1: 0.9551 - val_loss: 0.9303 - val_accuracy: 0.7770 - val_get_f1: 0.7796
# Epoch 35/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1244 - accuracy: 0.9575 - get_f1: 0.9573 - val_loss: 0.9523 - val_accuracy: 0.7725 - val_get_f1: 0.7749
# Epoch 36/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1049 - accuracy: 0.9643 - get_f1: 0.9630 - val_loss: 0.9855 - val_accuracy: 0.7725 - val_get_f1: 0.7711
# Epoch 37/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1102 - accuracy: 0.9615 - get_f1: 0.9610 - val_loss: 0.9903 - val_accuracy: 0.7660 - val_get_f1: 0.7681
# Epoch 38/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.1070 - accuracy: 0.9626 - get_f1: 0.9629 - val_loss: 1.0061 - val_accuracy: 0.7740 - val_get_f1: 0.7765
# Epoch 39/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.1131 - accuracy: 0.9609 - get_f1: 0.9617 - val_loss: 0.9808 - val_accuracy: 0.7745 - val_get_f1: 0.7772
# Epoch 40/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0933 - accuracy: 0.9671 - get_f1: 0.9668 - val_loss: 1.0123 - val_accuracy: 0.7735 - val_get_f1: 0.7754
# Epoch 41/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0842 - accuracy: 0.9718 - get_f1: 0.9718 - val_loss: 1.0628 - val_accuracy: 0.7725 - val_get_f1: 0.7719
# Epoch 42/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0788 - accuracy: 0.9715 - get_f1: 0.9711 - val_loss: 1.0548 - val_accuracy: 0.7820 - val_get_f1: 0.7838
# Epoch 43/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0926 - accuracy: 0.9671 - get_f1: 0.9677 - val_loss: 1.0089 - val_accuracy: 0.7860 - val_get_f1: 0.7894
# Epoch 44/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0872 - accuracy: 0.9681 - get_f1: 0.9683 - val_loss: 1.0559 - val_accuracy: 0.7795 - val_get_f1: 0.7789
# Epoch 45/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0763 - accuracy: 0.9725 - get_f1: 0.9728 - val_loss: 1.0403 - val_accuracy: 0.7820 - val_get_f1: 0.7828
# Epoch 46/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0774 - accuracy: 0.9731 - get_f1: 0.9741 - val_loss: 1.0678 - val_accuracy: 0.7850 - val_get_f1: 0.7846
# Epoch 47/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0807 - accuracy: 0.9716 - get_f1: 0.9716 - val_loss: 1.1794 - val_accuracy: 0.7640 - val_get_f1: 0.7648
# Epoch 48/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0859 - accuracy: 0.9690 - get_f1: 0.9691 - val_loss: 1.1118 - val_accuracy: 0.7750 - val_get_f1: 0.7777
# Epoch 49/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0735 - accuracy: 0.9750 - get_f1: 0.9755 - val_loss: 1.1478 - val_accuracy: 0.7635 - val_get_f1: 0.7667
# Epoch 50/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0702 - accuracy: 0.9755 - get_f1: 0.9753 - val_loss: 1.0558 - val_accuracy: 0.7840 - val_get_f1: 0.7852
# Epoch 51/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0645 - accuracy: 0.9783 - get_f1: 0.9780 - val_loss: 1.0795 - val_accuracy: 0.7835 - val_get_f1: 0.7854
# Epoch 52/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0578 - accuracy: 0.9800 - get_f1: 0.9797 - val_loss: 1.0672 - val_accuracy: 0.7845 - val_get_f1: 0.7860
# Epoch 53/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0674 - accuracy: 0.9775 - get_f1: 0.9775 - val_loss: 1.0965 - val_accuracy: 0.7770 - val_get_f1: 0.7770
# Epoch 54/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0637 - accuracy: 0.9762 - get_f1: 0.9763 - val_loss: 1.1674 - val_accuracy: 0.7755 - val_get_f1: 0.7758
# Epoch 55/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0551 - accuracy: 0.9819 - get_f1: 0.9822 - val_loss: 1.1777 - val_accuracy: 0.7740 - val_get_f1: 0.7728
# Epoch 56/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0582 - accuracy: 0.9803 - get_f1: 0.9806 - val_loss: 1.1580 - val_accuracy: 0.7860 - val_get_f1: 0.7887
# Epoch 57/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0576 - accuracy: 0.9796 - get_f1: 0.9795 - val_loss: 1.1191 - val_accuracy: 0.7810 - val_get_f1: 0.7825
# Epoch 58/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0616 - accuracy: 0.9791 - get_f1: 0.9792 - val_loss: 1.1677 - val_accuracy: 0.7865 - val_get_f1: 0.7875
# Epoch 59/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0470 - accuracy: 0.9844 - get_f1: 0.9843 - val_loss: 1.0967 - val_accuracy: 0.7930 - val_get_f1: 0.7961
# Epoch 60/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0534 - accuracy: 0.9811 - get_f1: 0.9812 - val_loss: 1.1668 - val_accuracy: 0.7735 - val_get_f1: 0.7763
# Epoch 61/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0481 - accuracy: 0.9835 - get_f1: 0.9832 - val_loss: 1.1260 - val_accuracy: 0.7885 - val_get_f1: 0.7921
# Epoch 62/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0552 - accuracy: 0.9800 - get_f1: 0.9802 - val_loss: 1.1029 - val_accuracy: 0.7825 - val_get_f1: 0.7832
# Epoch 63/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0583 - accuracy: 0.9793 - get_f1: 0.9793 - val_loss: 1.1463 - val_accuracy: 0.7790 - val_get_f1: 0.7800
# Epoch 64/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0579 - accuracy: 0.9804 - get_f1: 0.9807 - val_loss: 1.0539 - val_accuracy: 0.7885 - val_get_f1: 0.7875
# Epoch 65/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0528 - accuracy: 0.9820 - get_f1: 0.9821 - val_loss: 1.1285 - val_accuracy: 0.7785 - val_get_f1: 0.7789
# Epoch 66/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0499 - accuracy: 0.9831 - get_f1: 0.9832 - val_loss: 1.1187 - val_accuracy: 0.7785 - val_get_f1: 0.7813
# Epoch 67/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0473 - accuracy: 0.9827 - get_f1: 0.9823 - val_loss: 1.0852 - val_accuracy: 0.7965 - val_get_f1: 0.7980
# Epoch 68/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0403 - accuracy: 0.9869 - get_f1: 0.9868 - val_loss: 1.1657 - val_accuracy: 0.7945 - val_get_f1: 0.7947
# Epoch 69/70
# 63/63 [==============================] - 69s 1s/step - loss: 0.0513 - accuracy: 0.9805 - get_f1: 0.9808 - val_loss: 1.3231 - val_accuracy: 0.7670 - val_get_f1: 0.7696
# Epoch 70/70
# 63/63 [==============================] - 70s 1s/step - loss: 0.0617 - accuracy: 0.9778 - get_f1: 0.9776 - val_loss: 1.1618 - val_accuracy: 0.7925 - val_get_f1: 0.7934
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved/saved_cnn11_3/assets
# INFO:tensorflow:Assets written to: saved/saved_cnn11_3/assets

# %%
metrics = model_history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
test_loss, test_acc, _ = model.evaluate(vali_generator, batch_size=128)
print("The test Loss is :", test_loss)
print("\nThe Best test Accuracy is :", test_acc*100)
# Out:
# 16/16 [==============================] - 14s 855ms/step - loss: 1.1618 - accuracy: 0.7925 - get_f1: 0.7952
# The test Loss is : 1.161819577217102
#
# The Best test Accuracy is : 79.25000190734863

# %%
class estimator:
  _estimator_type = ''
  classes_=[]
  def __init__(self, model, classes):
    self.model = model
    self._estimator_type = 'classifier'
    self.classes_ = classes
  def predict(self, X):
    y_prob= self.model.predict(X)
    y_pred = y_prob.argmax(axis=1)
    return y_pred

classifier = estimator(model, genres)
figsize = (12,12)

x, y = zip(*(vali_generator[i] for i in range(len(vali_generator))))
x_val, y_val = np.vstack(x), np.vstack(y)
y_val = np.argmax(y_val, axis=1)

# %%
ConfusionMatrixDisplay.from_estimator(classifier, x_val, y_val, cmap='Blues', display_labels=genres ,normalize='true', ax=plt.subplots(figsize=figsize)[1])
# Out:
# 2022-11-19 22:44:46.476683: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 3981312000 exceeds 10% of free system memory.
# 2022-11-19 22:44:48.995355: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 3981312000 exceeds 10% of free system memory.
# 63/63 [==============================] - 2s 18ms/step

# %%
import pathlib
input_dir = pathlib.Path("input/")
audio_file_name = "chopin.wav"
sample_dir = "input/samples/"
audio_seg_dir = "input/audio_segments/"

predictions = []

if not input_dir.exists():
    os.mkdir("input")
    os.mkdir(sample_dir)
    os.mkdir(audio_seg_dir)

sample, sample_sr = librosa.load(os.path.join(sample_dir, audio_file_name))
sample_duration = int(librosa.get_duration(y=sample, sr=sample_sr))
Audio(sample, rate=sample_sr)

for i in range(int(sample_duration/3)): 
    t1 = i * 3 * 1000 #Works in milliseconds
    t2 = (i+1) * 3 * 1000
    newAudio = AudioSegment.from_wav(os.path.join(sample_dir, audio_file_name))
    newAudio = newAudio[t1:t2]
    newAudio.export(audio_seg_dir + 'audio_seg_' + str(i) +'.wav', format="wav") #Exports to a wav file in the current path.

from keras.utils import load_img, img_to_array

for af in os.listdir(audio_seg_dir):
    audio, sr = librosa.load(os.path.join(audio_seg_dir, af))
    mels = librosa.feature.melspectrogram(y=audio,sr=sr)
    fig = plt.Figure()
    canvas = FigureCanvas(fig)
    p = plt.imshow(librosa.power_to_db(mels,ref=np.max))

    spec_dir = "input/specs_segments"

    if not os.path.exists(spec_dir):
        os.mkdir(spec_dir)

    plt.savefig(os.path.join(spec_dir, af[:-3] + 'png'))

    image_data = load_img(os.path.join(spec_dir, af[:-3] + 'png'),color_mode='rgba',target_size=(288,432))
    image = img_to_array(image_data)
    image = np.reshape(image,(1,288,432,4))

    p = model.predict(image/255)
    p = p.reshape((10,))

    predictions.append(p)
# Out:
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
avg_preds = [x / len(predictions) for x in np.array(predictions).sum(axis=0)]
predicted_label = np.argmax(avg_preds)

print("The Predicted Label was: " + genres[predicted_label])
# Out:
# The Predicted Label was: classical

# %%
plt.figure(figsize=(30,10))
plt.bar(genres, np.array(avg_preds))
plt.title("Inference Results")
plt.show()
