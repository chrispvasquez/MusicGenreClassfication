# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2022-11-16 04:36:34.902957: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 04:36:36.590731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:36.606114: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:36.606224: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
datasetPath = "../content"

# %%
# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

if not os.path.exists('{datasetPath}'):
  os.makedirs('{datasetPath}/')
  os.makedirs('{datasetPath}/spectrograms30sec')
  os.makedirs('{datasetPath}/spectrograms30sec/train')
  os.makedirs('{datasetPath}/spectrograms30sec/test')

  for g in genres:
    path_audio = os.path.join('{datasetPath}/audio3sec',f'{g}')
    os.makedirs(path_audio)
    path_train = os.path.join('{datasetPath}/spectrograms30sec/train',f'{g}')
    path_test = os.path.join('{datasetPath}/spectrograms30sec/test',f'{g}')
    os.makedirs(path_train)
    os.makedirs(path_test)

# %%
# import librosa.display
# audio, sr = librosa.load('{datasetPath}/genres/jazz/jazz.00054.wav')

# D = np.abs(librosa.stft(audio))
# DB = librosa.amplitude_to_db(D, ref = np.max)

# plt.figure(figsize = (4.3, 2.8))
# p = librosa.display.specshow(DB, sr = sr)

# plt.savefig(os.path.join('{datasetPath}/spectrograms30sec/train/jazz/jazz00054.jpg'))

# %%
directory = "{datasetPath}/spectrograms30sec/train/"
for g in genres:
  if len(os.listdir(os.path.join('{datasetPath}/spectrograms30sec/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:10]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,"{datasetPath}/spectrograms30sec/test/" + f"{g}")

# %%
train_dir = "{datasetPath}/spectrograms30sec/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(288,432),color_mode="rgba",class_mode='categorical',batch_size=128)

validation_dir = "{datasetPath}/spectrograms30sec/test/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(288,432),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 900 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
def GenreModel(input_shape = (288,432,4),classes=10):
  
  X_input = Input(input_shape)

  X = Conv2D(8,kernel_size=(3,3),strides=(1,1))(X_input)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(16,kernel_size=(3,3),strides = (1,1))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(32,kernel_size=(3,3),strides = (1,1))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  X = Conv2D(64,kernel_size=(3,3),strides=(1,1))(X)
  X = BatchNormalization(axis=-1)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(128,kernel_size=(3,3),strides=(1,1))(X)
  X = BatchNormalization(axis=-1)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  
  X = Flatten()(X)
  
  X = Dropout(rate=0.3)(X)

  X = Dense(classes, activation='softmax', name='fc' + str(classes))(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# checkpoint_path = "saved_cnn2/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=True,
#                                                 verbose=1)

model = GenreModel(input_shape=(288,432,4), classes=10)
opt = Adam(learning_rate=0.0005)
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy',get_f1])
# Out:
# 2022-11-16 04:36:36.802308: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 04:36:36.803178: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:36.803358: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:36.803480: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:37.111089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:37.111215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:37.111358: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:36:37.111437: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13618 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 288, 432, 4)]     0
#
#  conv2d (Conv2D)             (None, 286, 430, 8)       296
#
#  batch_normalization (BatchN  (None, 286, 430, 8)      32
#  ormalization)
#
#  activation (Activation)     (None, 286, 430, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 143, 215, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 141, 213, 16)      1168
#
#  batch_normalization_1 (Batc  (None, 141, 213, 16)     64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 141, 213, 16)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 106, 16)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 68, 104, 32)       4640
#
#  batch_normalization_2 (Batc  (None, 68, 104, 32)      128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 68, 104, 32)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 34, 52, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 50, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 32, 50, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 50, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 25, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 23, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 14, 23, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 14, 23, 128)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 11, 128)       0
#  2D)
#
#  flatten (Flatten)           (None, 9856)              0
#
#  dropout (Dropout)           (None, 9856)              0
#
#  fc10 (Dense)                (None, 10)                98570
#
# =================================================================
# Total params: 198,018
# Trainable params: 197,522
# Non-trainable params: 496
# _________________________________________________________________

# %%
if os.path.exists("saved/saved_cnn2_30"):
    model_history = model.load_model("saved_cnn2_30")
else:
    model_history = model.fit_generator(train_generator,epochs=70,validation_data=vali_generator)
    model.save("saved/saved_cnn2_30")
# Out:
# /tmp/ipykernel_31644/3074449311.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=70,validation_data=vali_generator)
# Epoch 1/70
# 2022-11-16 04:36:38.973825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# 2022-11-16 04:36:40.238490: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 8/8 [==============================] - 7s 495ms/step - loss: 3.8791 - accuracy: 0.1444 - get_f1: 0.1464 - val_loss: 2.3024 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 2/70
# 8/8 [==============================] - 3s 417ms/step - loss: 2.5734 - accuracy: 0.2622 - get_f1: 0.2724 - val_loss: 2.3072 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 3/70
# 8/8 [==============================] - 3s 422ms/step - loss: 2.0048 - accuracy: 0.3533 - get_f1: 0.3190 - val_loss: 2.3691 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 4/70
# 8/8 [==============================] - 3s 411ms/step - loss: 1.6087 - accuracy: 0.4656 - get_f1: 0.4162 - val_loss: 2.4914 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 5/70
# 8/8 [==============================] - 3s 413ms/step - loss: 1.4838 - accuracy: 0.4789 - get_f1: 0.3926 - val_loss: 2.5563 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 6/70
# 8/8 [==============================] - 3s 394ms/step - loss: 1.3119 - accuracy: 0.5211 - get_f1: 0.4840 - val_loss: 2.8331 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 7/70
# 8/8 [==============================] - 3s 402ms/step - loss: 1.3351 - accuracy: 0.5478 - get_f1: 0.5417 - val_loss: 2.9685 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 8/70
# 8/8 [==============================] - 3s 415ms/step - loss: 1.1993 - accuracy: 0.5989 - get_f1: 0.5554 - val_loss: 3.3945 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 9/70
# 8/8 [==============================] - 3s 409ms/step - loss: 1.1705 - accuracy: 0.5978 - get_f1: 0.5225 - val_loss: 3.2072 - val_accuracy: 0.1200 - val_get_f1: 0.0000e+00
# Epoch 10/70
# 8/8 [==============================] - 3s 396ms/step - loss: 0.9847 - accuracy: 0.6389 - get_f1: 0.6510 - val_loss: 3.4275 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 11/70
# 8/8 [==============================] - 3s 408ms/step - loss: 0.9420 - accuracy: 0.6900 - get_f1: 0.6624 - val_loss: 3.6125 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 12/70
# 8/8 [==============================] - 3s 423ms/step - loss: 0.9182 - accuracy: 0.6922 - get_f1: 0.6395 - val_loss: 3.7453 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 13/70
# 8/8 [==============================] - 3s 415ms/step - loss: 1.0192 - accuracy: 0.6389 - get_f1: 0.6707 - val_loss: 3.8037 - val_accuracy: 0.1000 - val_get_f1: 0.0920
# Epoch 14/70
# 8/8 [==============================] - 3s 394ms/step - loss: 0.9611 - accuracy: 0.6689 - get_f1: 0.6832 - val_loss: 3.9809 - val_accuracy: 0.1000 - val_get_f1: 0.0000e+00
# Epoch 15/70
# 8/8 [==============================] - 3s 419ms/step - loss: 0.7253 - accuracy: 0.7478 - get_f1: 0.7084 - val_loss: 4.0966 - val_accuracy: 0.1000 - val_get_f1: 0.1005
# Epoch 16/70
# 8/8 [==============================] - 3s 423ms/step - loss: 0.8059 - accuracy: 0.7378 - get_f1: 0.7518 - val_loss: 4.0994 - val_accuracy: 0.1900 - val_get_f1: 0.0000e+00
# Epoch 17/70
# 8/8 [==============================] - 3s 423ms/step - loss: 0.5885 - accuracy: 0.8089 - get_f1: 0.7862 - val_loss: 3.9912 - val_accuracy: 0.1000 - val_get_f1: 0.1047
# Epoch 18/70
# 8/8 [==============================] - 3s 416ms/step - loss: 0.6900 - accuracy: 0.7600 - get_f1: 0.7411 - val_loss: 4.4959 - val_accuracy: 0.1900 - val_get_f1: 0.1565
# Epoch 19/70
# 8/8 [==============================] - 3s 412ms/step - loss: 0.5244 - accuracy: 0.8211 - get_f1: 0.8269 - val_loss: 4.3530 - val_accuracy: 0.2000 - val_get_f1: 0.1308
# Epoch 20/70
# 8/8 [==============================] - 3s 421ms/step - loss: 0.4303 - accuracy: 0.8544 - get_f1: 0.8418 - val_loss: 4.4402 - val_accuracy: 0.1000 - val_get_f1: 0.1058
# Epoch 21/70
# 8/8 [==============================] - 3s 421ms/step - loss: 0.5345 - accuracy: 0.8111 - get_f1: 0.8011 - val_loss: 4.7804 - val_accuracy: 0.1900 - val_get_f1: 0.2154
# Epoch 22/70
# 8/8 [==============================] - 3s 413ms/step - loss: 0.5712 - accuracy: 0.8044 - get_f1: 0.8269 - val_loss: 5.0410 - val_accuracy: 0.1000 - val_get_f1: 0.1005
# Epoch 23/70
# 8/8 [==============================] - 3s 427ms/step - loss: 0.3879 - accuracy: 0.8656 - get_f1: 0.8864 - val_loss: 4.4852 - val_accuracy: 0.1900 - val_get_f1: 0.1675
# Epoch 24/70
# 8/8 [==============================] - 3s 405ms/step - loss: 0.2454 - accuracy: 0.9278 - get_f1: 0.9271 - val_loss: 4.8956 - val_accuracy: 0.1900 - val_get_f1: 0.1753
# Epoch 25/70
# 8/8 [==============================] - 3s 416ms/step - loss: 0.2244 - accuracy: 0.9289 - get_f1: 0.9410 - val_loss: 4.5682 - val_accuracy: 0.1900 - val_get_f1: 0.1959
# Epoch 26/70
# 8/8 [==============================] - 4s 429ms/step - loss: 0.2501 - accuracy: 0.9233 - get_f1: 0.9284 - val_loss: 4.7340 - val_accuracy: 0.1900 - val_get_f1: 0.1990
# Epoch 27/70
# 8/8 [==============================] - 3s 407ms/step - loss: 0.1916 - accuracy: 0.9444 - get_f1: 0.9507 - val_loss: 4.9057 - val_accuracy: 0.2000 - val_get_f1: 0.2151
# Epoch 28/70
# 8/8 [==============================] - 3s 399ms/step - loss: 0.1402 - accuracy: 0.9722 - get_f1: 0.9554 - val_loss: 4.5901 - val_accuracy: 0.1900 - val_get_f1: 0.2000
# Epoch 29/70
# 8/8 [==============================] - 3s 417ms/step - loss: 0.2355 - accuracy: 0.9189 - get_f1: 0.8944 - val_loss: 5.2188 - val_accuracy: 0.1900 - val_get_f1: 0.1905
# Epoch 30/70
# 8/8 [==============================] - 4s 430ms/step - loss: 0.2300 - accuracy: 0.9322 - get_f1: 0.9382 - val_loss: 4.6883 - val_accuracy: 0.1900 - val_get_f1: 0.2135
# Epoch 31/70
# 8/8 [==============================] - 3s 411ms/step - loss: 0.1733 - accuracy: 0.9511 - get_f1: 0.9514 - val_loss: 5.2633 - val_accuracy: 0.1900 - val_get_f1: 0.1990
# Epoch 32/70
# 8/8 [==============================] - 3s 410ms/step - loss: 0.1038 - accuracy: 0.9833 - get_f1: 0.9828 - val_loss: 4.6331 - val_accuracy: 0.2000 - val_get_f1: 0.2062
# Epoch 33/70
# 8/8 [==============================] - 3s 423ms/step - loss: 0.0909 - accuracy: 0.9844 - get_f1: 0.9838 - val_loss: 5.1920 - val_accuracy: 0.1900 - val_get_f1: 0.1949
# Epoch 34/70
# 8/8 [==============================] - 3s 416ms/step - loss: 0.1007 - accuracy: 0.9789 - get_f1: 0.9793 - val_loss: 4.8420 - val_accuracy: 0.1700 - val_get_f1: 0.1554
# Epoch 35/70
# 8/8 [==============================] - 3s 418ms/step - loss: 0.1483 - accuracy: 0.9544 - get_f1: 0.9627 - val_loss: 5.3403 - val_accuracy: 0.1900 - val_get_f1: 0.1929
# Epoch 36/70
# 8/8 [==============================] - 3s 420ms/step - loss: 0.1232 - accuracy: 0.9700 - get_f1: 0.9723 - val_loss: 5.0733 - val_accuracy: 0.1900 - val_get_f1: 0.1959
# Epoch 37/70
# 8/8 [==============================] - 3s 420ms/step - loss: 0.1319 - accuracy: 0.9689 - get_f1: 0.9427 - val_loss: 4.9380 - val_accuracy: 0.1900 - val_get_f1: 0.1959
# Epoch 38/70
# 8/8 [==============================] - 3s 462ms/step - loss: 0.1033 - accuracy: 0.9756 - get_f1: 0.9768 - val_loss: 5.3770 - val_accuracy: 0.1900 - val_get_f1: 0.1919
# Epoch 39/70
# 8/8 [==============================] - 3s 412ms/step - loss: 0.0855 - accuracy: 0.9822 - get_f1: 0.9679 - val_loss: 5.0522 - val_accuracy: 0.1900 - val_get_f1: 0.1939
# Epoch 40/70
# 8/8 [==============================] - 3s 408ms/step - loss: 0.1105 - accuracy: 0.9778 - get_f1: 0.9804 - val_loss: 4.8428 - val_accuracy: 0.1900 - val_get_f1: 0.1959
# Epoch 41/70
# 8/8 [==============================] - 3s 414ms/step - loss: 0.1888 - accuracy: 0.9467 - get_f1: 0.9222 - val_loss: 6.5556 - val_accuracy: 0.1900 - val_get_f1: 0.1900
# Epoch 42/70
# 8/8 [==============================] - 3s 407ms/step - loss: 0.1359 - accuracy: 0.9556 - get_f1: 0.9624 - val_loss: 4.2940 - val_accuracy: 0.2000 - val_get_f1: 0.2151
# Epoch 43/70
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0959 - accuracy: 0.9811 - get_f1: 0.9798 - val_loss: 5.5736 - val_accuracy: 0.2000 - val_get_f1: 0.2020
# Epoch 44/70
# 8/8 [==============================] - 3s 406ms/step - loss: 0.0720 - accuracy: 0.9900 - get_f1: 0.9871 - val_loss: 5.3778 - val_accuracy: 0.2000 - val_get_f1: 0.2010
# Epoch 45/70
# 8/8 [==============================] - 3s 422ms/step - loss: 0.0750 - accuracy: 0.9856 - get_f1: 0.9852 - val_loss: 3.8451 - val_accuracy: 0.2100 - val_get_f1: 0.2186
# Epoch 46/70
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0503 - accuracy: 0.9967 - get_f1: 0.9961 - val_loss: 3.2949 - val_accuracy: 0.2800 - val_get_f1: 0.2857
# Epoch 47/70
# 8/8 [==============================] - 3s 414ms/step - loss: 0.0694 - accuracy: 0.9867 - get_f1: 0.9883 - val_loss: 3.5743 - val_accuracy: 0.2100 - val_get_f1: 0.2260
# Epoch 48/70
# 8/8 [==============================] - 3s 417ms/step - loss: 0.0739 - accuracy: 0.9778 - get_f1: 0.9799 - val_loss: 4.0615 - val_accuracy: 0.2200 - val_get_f1: 0.2270
# Epoch 49/70
# 8/8 [==============================] - 3s 419ms/step - loss: 0.0537 - accuracy: 0.9922 - get_f1: 0.9917 - val_loss: 3.6599 - val_accuracy: 0.2200 - val_get_f1: 0.2333
# Epoch 50/70
# 8/8 [==============================] - 3s 416ms/step - loss: 0.0393 - accuracy: 0.9956 - get_f1: 0.9961 - val_loss: 3.5148 - val_accuracy: 0.2500 - val_get_f1: 0.2444
# Epoch 51/70
# 8/8 [==============================] - 3s 406ms/step - loss: 0.0389 - accuracy: 0.9978 - get_f1: 0.9980 - val_loss: 3.5497 - val_accuracy: 0.2500 - val_get_f1: 0.2246
# Epoch 52/70
# 8/8 [==============================] - 3s 401ms/step - loss: 0.1513 - accuracy: 0.9633 - get_f1: 0.9348 - val_loss: 3.2574 - val_accuracy: 0.3000 - val_get_f1: 0.3034
# Epoch 53/70
# 8/8 [==============================] - 3s 461ms/step - loss: 0.1689 - accuracy: 0.9500 - get_f1: 0.9385 - val_loss: 4.0116 - val_accuracy: 0.2500 - val_get_f1: 0.2246
# Epoch 54/70
# 8/8 [==============================] - 3s 469ms/step - loss: 0.3604 - accuracy: 0.8989 - get_f1: 0.8853 - val_loss: 3.8629 - val_accuracy: 0.2800 - val_get_f1: 0.2623
# Epoch 55/70
# 8/8 [==============================] - 3s 402ms/step - loss: 0.1659 - accuracy: 0.9511 - get_f1: 0.9546 - val_loss: 3.4481 - val_accuracy: 0.3000 - val_get_f1: 0.2766
# Epoch 56/70
# 8/8 [==============================] - 3s 412ms/step - loss: 0.0714 - accuracy: 0.9878 - get_f1: 0.9892 - val_loss: 2.4278 - val_accuracy: 0.3900 - val_get_f1: 0.3846
# Epoch 57/70
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0610 - accuracy: 0.9933 - get_f1: 0.9936 - val_loss: 2.2061 - val_accuracy: 0.4600 - val_get_f1: 0.4246
# Epoch 58/70
# 8/8 [==============================] - 3s 411ms/step - loss: 0.2440 - accuracy: 0.9311 - get_f1: 0.9122 - val_loss: 2.2510 - val_accuracy: 0.4400 - val_get_f1: 0.4520
# Epoch 59/70
# 8/8 [==============================] - 3s 412ms/step - loss: 0.1694 - accuracy: 0.9400 - get_f1: 0.9473 - val_loss: 1.9696 - val_accuracy: 0.5300 - val_get_f1: 0.4891
# Epoch 60/70
# 8/8 [==============================] - 3s 406ms/step - loss: 0.1077 - accuracy: 0.9733 - get_f1: 0.9753 - val_loss: 1.7852 - val_accuracy: 0.5200 - val_get_f1: 0.5198
# Epoch 61/70
# 8/8 [==============================] - 3s 409ms/step - loss: 0.0679 - accuracy: 0.9833 - get_f1: 0.9872 - val_loss: 1.9125 - val_accuracy: 0.5100 - val_get_f1: 0.5165
# Epoch 62/70
# 8/8 [==============================] - 3s 418ms/step - loss: 0.0475 - accuracy: 0.9944 - get_f1: 0.9951 - val_loss: 1.7940 - val_accuracy: 0.5500 - val_get_f1: 0.5304
# Epoch 63/70
# 8/8 [==============================] - 3s 398ms/step - loss: 0.0358 - accuracy: 0.9967 - get_f1: 0.9966 - val_loss: 1.7347 - val_accuracy: 0.5600 - val_get_f1: 0.5363
# Epoch 64/70
# 8/8 [==============================] - 3s 416ms/step - loss: 0.0282 - accuracy: 0.9978 - get_f1: 0.9966 - val_loss: 1.7931 - val_accuracy: 0.5600 - val_get_f1: 0.5638
# Epoch 65/70
# 8/8 [==============================] - 3s 405ms/step - loss: 0.0233 - accuracy: 0.9978 - get_f1: 0.9985 - val_loss: 1.7485 - val_accuracy: 0.5800 - val_get_f1: 0.5838
# Epoch 66/70
# 8/8 [==============================] - 3s 408ms/step - loss: 0.0215 - accuracy: 0.9989 - get_f1: 0.9990 - val_loss: 1.6441 - val_accuracy: 0.6000 - val_get_f1: 0.6129
# Epoch 67/70
# 8/8 [==============================] - 3s 403ms/step - loss: 0.0379 - accuracy: 0.9911 - get_f1: 0.9916 - val_loss: 1.9944 - val_accuracy: 0.5300 - val_get_f1: 0.5397
# Epoch 68/70
# 8/8 [==============================] - 3s 411ms/step - loss: 0.0422 - accuracy: 0.9867 - get_f1: 0.9714 - val_loss: 1.5321 - val_accuracy: 0.6300 - val_get_f1: 0.6270
# Epoch 69/70
# 8/8 [==============================] - 3s 407ms/step - loss: 0.0983 - accuracy: 0.9756 - get_f1: 0.9778 - val_loss: 2.1566 - val_accuracy: 0.5300 - val_get_f1: 0.5333
# Epoch 70/70
# 8/8 [==============================] - 3s 401ms/step - loss: 0.0527 - accuracy: 0.9878 - get_f1: 0.9897 - val_loss: 1.5843 - val_accuracy: 0.6000 - val_get_f1: 0.5668
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved/saved_cnn2_30/assets
# INFO:tensorflow:Assets written to: saved/saved_cnn2_30/assets

# %%
metrics = model_history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
test_loss, test_acc, _ = model.evaluate(vali_generator, batch_size=128)
print("The test Loss is :", test_loss)
print("\nThe Best test Accuracy is :", test_acc*100)
# Out:
# 1/1 [==============================] - 0s 391ms/step - loss: 1.5843 - accuracy: 0.6000 - get_f1: 0.5668
# The test Loss is : 1.5842880010604858
#
# The Best test Accuracy is : 60.00000238418579

# %%
class estimator:
  _estimator_type = ''
  classes_=[]
  def __init__(self, model, classes):
    self.model = model
    self._estimator_type = 'classifier'
    self.classes_ = classes
  def predict(self, X):
    y_prob= self.model.predict(X)
    y_pred = y_prob.argmax(axis=1)
    return y_pred

classifier = estimator(model, genres)
figsize = (12,12)

x, y = zip(*(vali_generator[i] for i in range(len(vali_generator))))
x_val, y_val = np.vstack(x), np.vstack(y)
y_val = np.argmax(y_val, axis=1)

# %%
ConfusionMatrixDisplay.from_estimator(classifier, x_val, y_val, cmap='Blues', display_labels=genres ,normalize='true', ax=plt.subplots(figsize=figsize)[1])
# Out:
# 4/4 [==============================] - 0s 8ms/step

# %%
import pathlib
input_dir = pathlib.Path("input/")
audio_file_name = "chopin.wav"
sample_dir = "input/samples/"
audio_seg_dir = "input/audio_segments/"

predictions = []

if not input_dir.exists():
    os.mkdir("input")
    os.mkdir(sample_dir)
    os.mkdir(audio_seg_dir)

sample, sample_sr = librosa.load(os.path.join(sample_dir, audio_file_name))
sample_duration = int(librosa.get_duration(y=sample, sr=sample_sr))
Audio(sample, rate=sample_sr)

for i in range(int(sample_duration/3)): 
    t1 = i * 3 * 1000 #Works in milliseconds
    t2 = (i+1) * 3 * 1000
    newAudio = AudioSegment.from_wav(os.path.join(sample_dir, audio_file_name))
    newAudio = newAudio[t1:t2]
    newAudio.export(audio_seg_dir + 'audio_seg_' + str(i) +'.wav', format="wav") #Exports to a wav file in the current path.

from keras.utils import load_img, img_to_array

for af in os.listdir(audio_seg_dir):
    audio, sr = librosa.load(os.path.join(audio_seg_dir, af))
    mels = librosa.feature.melspectrogram(y=audio,sr=sr)
    fig = plt.Figure()
    canvas = FigureCanvas(fig)
    p = plt.imshow(librosa.power_to_db(mels,ref=np.max))

    spec_dir = "input/specs_segments"

    if not os.path.exists(spec_dir):
        os.mkdir(spec_dir)

    plt.savefig(os.path.join(spec_dir, af[:-3] + 'png'))

    image_data = load_img(os.path.join(spec_dir, af[:-3] + 'png'),color_mode='rgba',target_size=(288,432))
    image = img_to_array(image_data)
    image = np.reshape(image,(1,288,432,4))

    p = model.predict(image/255)
    p = p.reshape((10,))

    predictions.append(p)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step

# %%
avg_preds = [x / len(predictions) for x in np.array(predictions).sum(axis=0)]
predicted_label = np.argmax(avg_preds)

print("The Predicted Label was: " + genres[predicted_label])
# Out:
# The Predicted Label was: metal

# %%
plt.figure(figsize=(30,10))
plt.bar(genres, np.array(avg_preds))
plt.title("Inference Results")
plt.show()
