# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout, GlobalAveragePooling2D
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2023-05-06 20:15:56.987264: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/chrispv/miniconda3/envs/tf-LSTM/lib/python3.8/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# 2023-05-06 20:15:59.408523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:15:59.432216: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:15:59.432480: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
datasetPath = "../../datasets"

# %%
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

# Split Into Training and Testing
directory = f"{datasetPath}/spectrogramsAlt3sec/train/"
for g in genres:
  if len(os.listdir(os.path.join(f'{datasetPath}/spectrogramsAlt3sec/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,f"{datasetPath}/spectrogramsAlt3sec/test/" + f"{g}")

# Split Into Training and Validation
directory = f"{datasetPath}/spectrogramsAlt3sec/train/"
for g in genres:
  if len(os.listdir(os.path.join(f'{datasetPath}/spectrogramsAlt3sec/valid/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,f"{datasetPath}/spectrogramsAlt3sec/valid/" + f"{g}")

# %%
train_dir = f"{datasetPath}/spectrogramsAlt3sec/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(26,65),color_mode="rgba",class_mode='categorical',batch_size=128)

test_dir = f"{datasetPath}/spectrogramsAlt3sec/test/"
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir,target_size=(26,65),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 8000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
validation_dir = f"{datasetPath}/spectrogramsAlt3sec/valid/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(26,65),color_mode='rgba',class_mode='categorical',batch_size=128)

def GenreModel(input_shape = (26,65, 4),classes=10):
  X_input = Input(input_shape)

  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X_input)

  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X)
  X = AveragePooling2D(pool_size=(3, 3), strides=(2,2),padding="same")(X)
  
  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X)
  X = AveragePooling2D(pool_size=(3, 3), strides=(2,2),padding="same")(X)

  X = Conv2D(512, kernel_size=(4,4), activation='relu',padding="valid")(X)
  X = GlobalAveragePooling2D()(X)

  X = Dense(256, activation='relu')(X)
  X = Dense(128, activation='relu')(X)
  X = Dense(10, activation='softmax')(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model
# Out:
# Found 1000 images belonging to 10 classes.

# %%
# checkpoint_path = "saved_cnn3/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=False,
#                                                 verbose=1)

model = GenreModel(input_shape=(26,65, 4), classes=10)
opt = Adam()
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# 2023-05-06 20:16:00.293214: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 20:16:00.294630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.294967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.295167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.782828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.783079: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.783090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-06 20:16:00.783287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 20:16:00.783333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21602 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 26, 65, 4)]       0
#
#  conv2d (Conv2D)             (None, 24, 63, 256)       9472
#
#  conv2d_1 (Conv2D)           (None, 22, 61, 256)       590080
#
#  average_pooling2d (AverageP  (None, 11, 31, 256)      0
#  ooling2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 29, 256)        590080
#
#  average_pooling2d_1 (Averag  (None, 5, 15, 256)       0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 12, 512)        2097664
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,452,810
# Trainable params: 3,452,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
fresh_model = True

from tensorflow.keras.callbacks import ModelCheckpoint

mc = ModelCheckpoint("saved/saved_cnn16_3.hdf5", save_best_only=True, monitor="val_loss", mode="min")
model_history = model.fit_generator(train_generator,epochs=140,validation_data=vali_generator, callbacks=[mc])

# if os.path.exists("../saved/saved_cnn16_3.h5"):
#     model_history = keras.models.load_model("../saved/saved_cnn16_3.h5")
# else:
#     model_history = model.fit_generator(train_generator,epochs=200,validation_data=vali_generator)
#     # model.save("../saved/saved_cnn16_3.h5")
#     fresh_model = True
# Out:
# /tmp/ipykernel_87654/2819009049.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=140,validation_data=vali_generator, callbacks=[mc])
# Epoch 1/140
# 2023-05-06 20:16:03.328270: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-05-06 20:16:05.924269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 63/63 [==============================] - 46s 659ms/step - loss: 2.0852 - accuracy: 0.2142 - val_loss: 1.8573 - val_accuracy: 0.3260
# Epoch 2/140
# 63/63 [==============================] - 29s 461ms/step - loss: 1.8629 - accuracy: 0.3031 - val_loss: 1.7824 - val_accuracy: 0.3320
# Epoch 3/140
# 63/63 [==============================] - 29s 457ms/step - loss: 1.7619 - accuracy: 0.3532 - val_loss: 1.6739 - val_accuracy: 0.3690
# Epoch 4/140
# 63/63 [==============================] - 29s 459ms/step - loss: 1.6430 - accuracy: 0.3890 - val_loss: 1.5613 - val_accuracy: 0.4190
# Epoch 5/140
# 63/63 [==============================] - 29s 458ms/step - loss: 1.5343 - accuracy: 0.4379 - val_loss: 1.5818 - val_accuracy: 0.4020
# Epoch 6/140
# 63/63 [==============================] - 31s 491ms/step - loss: 1.4873 - accuracy: 0.4514 - val_loss: 1.4169 - val_accuracy: 0.4690
# Epoch 7/140
# 63/63 [==============================] - 42s 668ms/step - loss: 1.3619 - accuracy: 0.5010 - val_loss: 1.2709 - val_accuracy: 0.5290
# Epoch 8/140
# 63/63 [==============================] - 42s 666ms/step - loss: 1.3128 - accuracy: 0.5214 - val_loss: 1.3282 - val_accuracy: 0.5220
# Epoch 9/140
# 63/63 [==============================] - 42s 666ms/step - loss: 1.2561 - accuracy: 0.5386 - val_loss: 1.2291 - val_accuracy: 0.5390
# Epoch 10/140
# 63/63 [==============================] - 42s 669ms/step - loss: 1.2054 - accuracy: 0.5608 - val_loss: 1.1823 - val_accuracy: 0.5530
# Epoch 11/140
# 63/63 [==============================] - 42s 664ms/step - loss: 1.1858 - accuracy: 0.5665 - val_loss: 1.1665 - val_accuracy: 0.5800
# Epoch 12/140
# 63/63 [==============================] - 42s 673ms/step - loss: 1.1646 - accuracy: 0.5757 - val_loss: 1.1065 - val_accuracy: 0.6000
# Epoch 13/140
# 63/63 [==============================] - 42s 671ms/step - loss: 1.0918 - accuracy: 0.6056 - val_loss: 1.0669 - val_accuracy: 0.6140
# Epoch 14/140
# 63/63 [==============================] - 42s 667ms/step - loss: 1.0442 - accuracy: 0.6231 - val_loss: 1.0819 - val_accuracy: 0.5890
# Epoch 15/140
# 63/63 [==============================] - 42s 670ms/step - loss: 1.0457 - accuracy: 0.6177 - val_loss: 1.0218 - val_accuracy: 0.6410
# Epoch 16/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.9824 - accuracy: 0.6436 - val_loss: 0.9894 - val_accuracy: 0.6420
# Epoch 17/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.9731 - accuracy: 0.6478 - val_loss: 1.0225 - val_accuracy: 0.6340
# Epoch 18/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.9364 - accuracy: 0.6597 - val_loss: 0.9771 - val_accuracy: 0.6320
# Epoch 19/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.8839 - accuracy: 0.6775 - val_loss: 0.9301 - val_accuracy: 0.6580
# Epoch 20/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.8835 - accuracy: 0.6741 - val_loss: 0.9014 - val_accuracy: 0.6820
# Epoch 21/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.8488 - accuracy: 0.6896 - val_loss: 0.8826 - val_accuracy: 0.6820
# Epoch 22/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.8022 - accuracy: 0.7100 - val_loss: 0.8757 - val_accuracy: 0.6730
# Epoch 23/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.8054 - accuracy: 0.7065 - val_loss: 0.8737 - val_accuracy: 0.6940
# Epoch 24/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.7731 - accuracy: 0.7175 - val_loss: 0.9149 - val_accuracy: 0.6750
# Epoch 25/140
# 63/63 [==============================] - 42s 671ms/step - loss: 0.7227 - accuracy: 0.7343 - val_loss: 0.8963 - val_accuracy: 0.6940
# Epoch 26/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.6974 - accuracy: 0.7505 - val_loss: 0.8456 - val_accuracy: 0.7070
# Epoch 27/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.6738 - accuracy: 0.7559 - val_loss: 0.8144 - val_accuracy: 0.6960
# Epoch 28/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.6668 - accuracy: 0.7582 - val_loss: 0.8570 - val_accuracy: 0.7140
# Epoch 29/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.6309 - accuracy: 0.7694 - val_loss: 0.8222 - val_accuracy: 0.7190
# Epoch 30/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.5957 - accuracy: 0.7864 - val_loss: 0.8242 - val_accuracy: 0.7180
# Epoch 31/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.5959 - accuracy: 0.7894 - val_loss: 0.8115 - val_accuracy: 0.7200
# Epoch 32/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.5616 - accuracy: 0.7943 - val_loss: 0.7986 - val_accuracy: 0.7380
# Epoch 33/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.5370 - accuracy: 0.8089 - val_loss: 0.7610 - val_accuracy: 0.7520
# Epoch 34/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.4815 - accuracy: 0.8276 - val_loss: 0.7427 - val_accuracy: 0.7650
# Epoch 35/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.4697 - accuracy: 0.8346 - val_loss: 0.7918 - val_accuracy: 0.7330
# Epoch 36/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.4698 - accuracy: 0.8241 - val_loss: 0.8359 - val_accuracy: 0.7180
# Epoch 37/140
# 63/63 [==============================] - 44s 694ms/step - loss: 0.4452 - accuracy: 0.8390 - val_loss: 0.7528 - val_accuracy: 0.7560
# Epoch 38/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.4142 - accuracy: 0.8457 - val_loss: 0.7629 - val_accuracy: 0.7450
# Epoch 39/140
# 63/63 [==============================] - 42s 658ms/step - loss: 0.4425 - accuracy: 0.8399 - val_loss: 0.8275 - val_accuracy: 0.7330
# Epoch 40/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.4186 - accuracy: 0.8431 - val_loss: 0.7405 - val_accuracy: 0.7820
# Epoch 41/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.3536 - accuracy: 0.8724 - val_loss: 0.8769 - val_accuracy: 0.7220
# Epoch 42/140
# 63/63 [==============================] - 42s 658ms/step - loss: 0.3685 - accuracy: 0.8645 - val_loss: 0.8020 - val_accuracy: 0.7570
# Epoch 43/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.3077 - accuracy: 0.8891 - val_loss: 0.8048 - val_accuracy: 0.7550
# Epoch 44/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.2865 - accuracy: 0.8957 - val_loss: 0.7833 - val_accuracy: 0.7700
# Epoch 45/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.2624 - accuracy: 0.9093 - val_loss: 0.7883 - val_accuracy: 0.7880
# Epoch 46/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.2562 - accuracy: 0.9082 - val_loss: 0.8032 - val_accuracy: 0.7660
# Epoch 47/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.2814 - accuracy: 0.8994 - val_loss: 0.8401 - val_accuracy: 0.7500
# Epoch 48/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.2532 - accuracy: 0.9059 - val_loss: 0.7103 - val_accuracy: 0.7940
# Epoch 49/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.2540 - accuracy: 0.9111 - val_loss: 0.7634 - val_accuracy: 0.7770
# Epoch 50/140
# 63/63 [==============================] - 42s 663ms/step - loss: 0.2381 - accuracy: 0.9139 - val_loss: 0.7735 - val_accuracy: 0.7820
# Epoch 51/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.1827 - accuracy: 0.9370 - val_loss: 0.7725 - val_accuracy: 0.8010
# Epoch 52/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.1731 - accuracy: 0.9369 - val_loss: 0.8527 - val_accuracy: 0.7770
# Epoch 53/140
# 63/63 [==============================] - 43s 677ms/step - loss: 0.1663 - accuracy: 0.9414 - val_loss: 0.8672 - val_accuracy: 0.7900
# Epoch 54/140
# 63/63 [==============================] - 42s 659ms/step - loss: 0.1983 - accuracy: 0.9316 - val_loss: 0.7473 - val_accuracy: 0.8030
# Epoch 55/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.1681 - accuracy: 0.9389 - val_loss: 0.8666 - val_accuracy: 0.7750
# Epoch 56/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.1684 - accuracy: 0.9410 - val_loss: 0.8720 - val_accuracy: 0.7990
# Epoch 57/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.1245 - accuracy: 0.9578 - val_loss: 0.8368 - val_accuracy: 0.8080
# Epoch 58/140
# 63/63 [==============================] - 42s 658ms/step - loss: 0.1166 - accuracy: 0.9596 - val_loss: 0.9977 - val_accuracy: 0.7750
# Epoch 59/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.1011 - accuracy: 0.9634 - val_loss: 0.8901 - val_accuracy: 0.7940
# Epoch 60/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.1395 - accuracy: 0.9496 - val_loss: 1.0648 - val_accuracy: 0.7830
# Epoch 61/140
# 63/63 [==============================] - 41s 656ms/step - loss: 0.1226 - accuracy: 0.9569 - val_loss: 0.9109 - val_accuracy: 0.8060
# Epoch 62/140
# 63/63 [==============================] - 42s 678ms/step - loss: 0.1084 - accuracy: 0.9624 - val_loss: 1.0154 - val_accuracy: 0.7870
# Epoch 63/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.1027 - accuracy: 0.9629 - val_loss: 0.8968 - val_accuracy: 0.7910
# Epoch 64/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.0893 - accuracy: 0.9700 - val_loss: 0.8066 - val_accuracy: 0.8110
# Epoch 65/140
# 63/63 [==============================] - 42s 663ms/step - loss: 0.0705 - accuracy: 0.9764 - val_loss: 1.1635 - val_accuracy: 0.7660
# Epoch 66/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.1059 - accuracy: 0.9629 - val_loss: 1.0232 - val_accuracy: 0.7950
# Epoch 67/140
# 63/63 [==============================] - 42s 657ms/step - loss: 0.0515 - accuracy: 0.9840 - val_loss: 0.9326 - val_accuracy: 0.8040
# Epoch 68/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.0489 - accuracy: 0.9844 - val_loss: 1.1194 - val_accuracy: 0.8020
# Epoch 69/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0556 - accuracy: 0.9812 - val_loss: 1.0019 - val_accuracy: 0.8040
# Epoch 70/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.0569 - accuracy: 0.9811 - val_loss: 1.0134 - val_accuracy: 0.8040
# Epoch 71/140
# 63/63 [==============================] - 42s 662ms/step - loss: 0.0868 - accuracy: 0.9701 - val_loss: 0.9589 - val_accuracy: 0.8070
# Epoch 72/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.0941 - accuracy: 0.9670 - val_loss: 1.0905 - val_accuracy: 0.7810
# Epoch 73/140
# 63/63 [==============================] - 42s 659ms/step - loss: 0.1110 - accuracy: 0.9588 - val_loss: 0.9114 - val_accuracy: 0.8100
# Epoch 74/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.0676 - accuracy: 0.9783 - val_loss: 1.0594 - val_accuracy: 0.8040
# Epoch 75/140
# 63/63 [==============================] - 42s 659ms/step - loss: 0.0507 - accuracy: 0.9824 - val_loss: 0.9726 - val_accuracy: 0.8170
# Epoch 76/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.0808 - accuracy: 0.9724 - val_loss: 1.1101 - val_accuracy: 0.8000
# Epoch 77/140
# 63/63 [==============================] - 42s 659ms/step - loss: 0.0789 - accuracy: 0.9718 - val_loss: 0.9558 - val_accuracy: 0.8140
# Epoch 78/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.0499 - accuracy: 0.9837 - val_loss: 0.9797 - val_accuracy: 0.8140
# Epoch 79/140
# 63/63 [==============================] - 42s 663ms/step - loss: 0.0291 - accuracy: 0.9930 - val_loss: 1.2114 - val_accuracy: 0.7820
# Epoch 80/140
# 63/63 [==============================] - 42s 660ms/step - loss: 0.0604 - accuracy: 0.9781 - val_loss: 1.0240 - val_accuracy: 0.7980
# Epoch 81/140
# 63/63 [==============================] - 43s 678ms/step - loss: 0.0647 - accuracy: 0.9797 - val_loss: 1.0051 - val_accuracy: 0.8040
# Epoch 82/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0334 - accuracy: 0.9894 - val_loss: 1.0765 - val_accuracy: 0.8210
# Epoch 83/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0515 - accuracy: 0.9826 - val_loss: 1.0687 - val_accuracy: 0.7950
# Epoch 84/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.1096 - accuracy: 0.9606 - val_loss: 0.9403 - val_accuracy: 0.8120
# Epoch 85/140
# 63/63 [==============================] - 42s 661ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.9771 - val_accuracy: 0.8250
# Epoch 86/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0118 - accuracy: 0.9973 - val_loss: 1.0332 - val_accuracy: 0.8320
# Epoch 87/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.1048 - accuracy: 0.9635 - val_loss: 1.0255 - val_accuracy: 0.7940
# Epoch 88/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0412 - accuracy: 0.9889 - val_loss: 0.9110 - val_accuracy: 0.8270
# Epoch 89/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0342 - accuracy: 0.9898 - val_loss: 1.0636 - val_accuracy: 0.8050
# Epoch 90/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.1013 - accuracy: 0.9656 - val_loss: 1.0635 - val_accuracy: 0.7750
# Epoch 91/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.0641 - accuracy: 0.9797 - val_loss: 0.8734 - val_accuracy: 0.8390
# Epoch 92/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 1.0150 - val_accuracy: 0.8260
# Epoch 93/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 1.0925 - val_accuracy: 0.8130
# Epoch 94/140
# 63/63 [==============================] - 42s 671ms/step - loss: 0.0258 - accuracy: 0.9924 - val_loss: 1.2165 - val_accuracy: 0.7980
# Epoch 95/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0405 - accuracy: 0.9865 - val_loss: 0.9771 - val_accuracy: 0.8300
# Epoch 96/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0277 - accuracy: 0.9921 - val_loss: 1.2757 - val_accuracy: 0.8070
# Epoch 97/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.0816 - accuracy: 0.9699 - val_loss: 1.0841 - val_accuracy: 0.8100
# Epoch 98/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0614 - accuracy: 0.9784 - val_loss: 1.1672 - val_accuracy: 0.7940
# Epoch 99/140
# 63/63 [==============================] - 42s 674ms/step - loss: 0.0467 - accuracy: 0.9843 - val_loss: 1.0048 - val_accuracy: 0.8030
# Epoch 100/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.0260 - accuracy: 0.9927 - val_loss: 1.0808 - val_accuracy: 0.8330
# Epoch 101/140
# 63/63 [==============================] - 42s 663ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 1.1761 - val_accuracy: 0.8140
# Epoch 102/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0215 - accuracy: 0.9925 - val_loss: 1.0499 - val_accuracy: 0.8270
# Epoch 103/140
# 63/63 [==============================] - 42s 671ms/step - loss: 0.0557 - accuracy: 0.9803 - val_loss: 1.1110 - val_accuracy: 0.7960
# Epoch 104/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0657 - accuracy: 0.9793 - val_loss: 1.1807 - val_accuracy: 0.8040
# Epoch 105/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.0708 - accuracy: 0.9770 - val_loss: 1.0979 - val_accuracy: 0.7990
# Epoch 106/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0223 - accuracy: 0.9941 - val_loss: 1.0327 - val_accuracy: 0.8220
# Epoch 107/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 1.0037 - val_accuracy: 0.8440
# Epoch 108/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 1.0248 - val_accuracy: 0.8350
# Epoch 109/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.0149 - val_accuracy: 0.8350
# Epoch 110/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 1.0312 - val_accuracy: 0.8440
# Epoch 111/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 1.0617 - val_accuracy: 0.8320
# Epoch 112/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 1.0854 - val_accuracy: 0.8300
# Epoch 113/140
# 63/63 [==============================] - 43s 674ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 1.1139 - val_accuracy: 0.8290
# Epoch 114/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 1.1259 - val_accuracy: 0.8340
# Epoch 115/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 1.1048 - val_accuracy: 0.8290
# Epoch 116/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.1603 - val_accuracy: 0.8300
# Epoch 117/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 1.0988 - val_accuracy: 0.8260
# Epoch 118/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 1.1759 - val_accuracy: 0.8350
# Epoch 119/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 1.1464 - val_accuracy: 0.8340
# Epoch 120/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 1.2390 - val_accuracy: 0.8200
# Epoch 121/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 1.3335 - val_accuracy: 0.8020
# Epoch 122/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.1945 - accuracy: 0.9379 - val_loss: 0.8624 - val_accuracy: 0.7800
# Epoch 123/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0786 - accuracy: 0.9745 - val_loss: 1.0093 - val_accuracy: 0.7970
# Epoch 124/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0913 - accuracy: 0.9694 - val_loss: 1.1669 - val_accuracy: 0.7650
# Epoch 125/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0655 - accuracy: 0.9783 - val_loss: 1.0364 - val_accuracy: 0.8160
# Epoch 126/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.0706 - accuracy: 0.9771 - val_loss: 1.1899 - val_accuracy: 0.7770
# Epoch 127/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0483 - accuracy: 0.9843 - val_loss: 1.1084 - val_accuracy: 0.8120
# Epoch 128/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.0371 - accuracy: 0.9879 - val_loss: 1.2909 - val_accuracy: 0.7980
# Epoch 129/140
# 63/63 [==============================] - 42s 671ms/step - loss: 0.0972 - accuracy: 0.9651 - val_loss: 1.0585 - val_accuracy: 0.7820
# Epoch 130/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.0375 - accuracy: 0.9870 - val_loss: 0.8940 - val_accuracy: 0.8280
# Epoch 131/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.9239 - val_accuracy: 0.8460
# Epoch 132/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.9711 - val_accuracy: 0.8450
# Epoch 133/140
# 63/63 [==============================] - 42s 664ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.9422 - val_accuracy: 0.8470
# Epoch 134/140
# 63/63 [==============================] - 42s 669ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 1.0066 - val_accuracy: 0.8390
# Epoch 135/140
# 63/63 [==============================] - 42s 667ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 1.0514 - val_accuracy: 0.8370
# Epoch 136/140
# 63/63 [==============================] - 42s 666ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 1.0446 - val_accuracy: 0.8410
# Epoch 137/140
# 63/63 [==============================] - 42s 665ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 1.0410 - val_accuracy: 0.8400
# Epoch 138/140
# 63/63 [==============================] - 42s 670ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 1.0275 - val_accuracy: 0.8400
# Epoch 139/140
# 63/63 [==============================] - 42s 672ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 1.0643 - val_accuracy: 0.8370
# Epoch 140/140
# 63/63 [==============================] - 42s 668ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 1.0618 - val_accuracy: 0.8290

# %%
if fresh_model:
    metrics = model_history.history
    plt.figure(figsize=(16,6))
    plt.subplot(1,2,1)
    plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
    plt.legend(['loss', 'val_loss'])
    plt.ylim([0, max(plt.ylim())])
    plt.xlabel('Epoch')
    plt.ylabel('Loss [CrossEntropy]')

    plt.subplot(1,2,2)
    plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
    plt.legend(['accuracy', 'val_accuracy'])
    plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy [%]')
