# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout, GlobalAveragePooling2D
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2023-05-06 19:19:51.476722: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/chrispv/miniconda3/envs/tf-LSTM/lib/python3.8/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# 2023-05-06 19:19:54.000113: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:54.022935: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:54.023202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
datasetPath = "../../datasets"

# %%
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

# Split Into Training and Testing
directory = f"{datasetPath}/spectrograms3sec/train/"
for g in genres:
  if len(os.listdir(os.path.join(f'{datasetPath}/spectrograms3sec/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,f"{datasetPath}/spectrograms3sec/test/" + f"{g}")

# Split Into Training and Validation
directory = f"{datasetPath}/spectrograms3sec/train/"
for g in genres:
  if len(os.listdir(os.path.join(f'{datasetPath}/spectrograms3sec/valid/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,f"{datasetPath}/spectrograms3sec/valid/" + f"{g}")

# %%
train_dir = f"{datasetPath}/spectrograms3sec/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(26,65),color_mode="rgba",class_mode='categorical',batch_size=128)

test_dir = f"{datasetPath}/spectrograms3sec/test/"
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir,target_size=(26,65),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 8000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
validation_dir = f"{datasetPath}/spectrograms3sec/valid/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(26,65),color_mode='rgba',class_mode='categorical',batch_size=128)

def GenreModel(input_shape = (26,65, 4),classes=10):
  X_input = Input(input_shape)

  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X_input)

  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X)
  X = AveragePooling2D(pool_size=(3, 3), strides=(2,2),padding="same")(X)
  
  X = Conv2D(256, kernel_size=(3,3), activation='relu',padding="valid")(X)
  X = AveragePooling2D(pool_size=(3, 3), strides=(2,2),padding="same")(X)

  X = Conv2D(512, kernel_size=(4,4), activation='relu',padding="valid")(X)
  X = GlobalAveragePooling2D()(X)

  X = Dense(256, activation='relu')(X)
  X = Dense(128, activation='relu')(X)
  X = Dense(10, activation='softmax')(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model
# Out:
# Found 1000 images belonging to 10 classes.

# %%
# checkpoint_path = "saved_cnn3/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=False,
#                                                 verbose=1)

model = GenreModel(input_shape=(26,65, 4), classes=10)
opt = Adam()
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# 2023-05-06 19:19:55.062751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 19:19:55.064263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.064531: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.064790: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.596226: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.596491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.596507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-06 19:19:55.596718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:0c:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-06 19:19:55.596756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20371 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 26, 65, 4)]       0
#
#  conv2d (Conv2D)             (None, 24, 63, 256)       9472
#
#  conv2d_1 (Conv2D)           (None, 22, 61, 256)       590080
#
#  average_pooling2d (AverageP  (None, 11, 31, 256)      0
#  ooling2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 29, 256)        590080
#
#  average_pooling2d_1 (Averag  (None, 5, 15, 256)       0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 12, 512)        2097664
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,452,810
# Trainable params: 3,452,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
fresh_model = True

from tensorflow.keras.callbacks import ModelCheckpoint

mc = ModelCheckpoint("saved/saved_cnn15_3.hdf5", save_best_only=True, monitor="val_loss", mode="min")
model_history = model.fit_generator(train_generator,epochs=140,validation_data=vali_generator, callbacks=[mc])

# if os.path.exists("../saved/saved_cnn15_3.h5"):
#     model_history = keras.models.load_model("../saved/saved_cnn15_3.h5")
# else:
#     model_history = model.fit_generator(train_generator,epochs=200,validation_data=vali_generator)
#     # model.save("../saved/saved_cnn14_3.h5")
#     fresh_model = True
# Out:
# /tmp/ipykernel_66926/809773661.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=140,validation_data=vali_generator, callbacks=[mc])
# Epoch 1/140
# 2023-05-06 19:20:20.497029: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-05-06 19:20:34.739383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 63/63 [==============================] - 52s 544ms/step - loss: 2.0816 - accuracy: 0.2183 - val_loss: 1.8706 - val_accuracy: 0.3090
# Epoch 2/140
# 63/63 [==============================] - 29s 457ms/step - loss: 1.8394 - accuracy: 0.3169 - val_loss: 1.7868 - val_accuracy: 0.3200
# Epoch 3/140
# 63/63 [==============================] - 29s 459ms/step - loss: 1.7051 - accuracy: 0.3710 - val_loss: 1.5671 - val_accuracy: 0.4150
# Epoch 4/140
# 63/63 [==============================] - 29s 457ms/step - loss: 1.5615 - accuracy: 0.4286 - val_loss: 1.4576 - val_accuracy: 0.4510
# Epoch 5/140
# 63/63 [==============================] - 22s 343ms/step - loss: 1.4743 - accuracy: 0.4543 - val_loss: 1.4276 - val_accuracy: 0.4820
# Epoch 6/140
# 63/63 [==============================] - 20s 313ms/step - loss: 1.4215 - accuracy: 0.4804 - val_loss: 1.3331 - val_accuracy: 0.5140
# Epoch 7/140
# 63/63 [==============================] - 20s 313ms/step - loss: 1.3281 - accuracy: 0.5179 - val_loss: 1.3237 - val_accuracy: 0.5180
# Epoch 8/140
# 63/63 [==============================] - 20s 315ms/step - loss: 1.2772 - accuracy: 0.5387 - val_loss: 1.2092 - val_accuracy: 0.5610
# Epoch 9/140
# 63/63 [==============================] - 21s 327ms/step - loss: 1.2753 - accuracy: 0.5344 - val_loss: 1.2560 - val_accuracy: 0.5360
# Epoch 10/140
# 63/63 [==============================] - 20s 318ms/step - loss: 1.2068 - accuracy: 0.5648 - val_loss: 1.1651 - val_accuracy: 0.5780
# Epoch 11/140
# 63/63 [==============================] - 20s 316ms/step - loss: 1.1966 - accuracy: 0.5681 - val_loss: 1.1714 - val_accuracy: 0.5940
# Epoch 12/140
# 63/63 [==============================] - 20s 317ms/step - loss: 1.1671 - accuracy: 0.5780 - val_loss: 1.1908 - val_accuracy: 0.5690
# Epoch 13/140
# 63/63 [==============================] - 20s 315ms/step - loss: 1.1066 - accuracy: 0.6028 - val_loss: 1.1593 - val_accuracy: 0.5810
# Epoch 14/140
# 63/63 [==============================] - 20s 319ms/step - loss: 1.0956 - accuracy: 0.6047 - val_loss: 1.0879 - val_accuracy: 0.6250
# Epoch 15/140
# 63/63 [==============================] - 23s 367ms/step - loss: 1.0839 - accuracy: 0.6110 - val_loss: 1.1189 - val_accuracy: 0.5880
# Epoch 16/140
# 63/63 [==============================] - 20s 314ms/step - loss: 1.0180 - accuracy: 0.6310 - val_loss: 1.0496 - val_accuracy: 0.6240
# Epoch 17/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.9993 - accuracy: 0.6374 - val_loss: 1.0872 - val_accuracy: 0.6050
# Epoch 18/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.9484 - accuracy: 0.6501 - val_loss: 1.0186 - val_accuracy: 0.6550
# Epoch 19/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.9429 - accuracy: 0.6579 - val_loss: 1.0491 - val_accuracy: 0.6150
# Epoch 20/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.8989 - accuracy: 0.6749 - val_loss: 1.0383 - val_accuracy: 0.6240
# Epoch 21/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.8634 - accuracy: 0.6831 - val_loss: 0.9251 - val_accuracy: 0.6570
# Epoch 22/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.8713 - accuracy: 0.6846 - val_loss: 1.0125 - val_accuracy: 0.6360
# Epoch 23/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.8206 - accuracy: 0.7023 - val_loss: 0.9165 - val_accuracy: 0.6800
# Epoch 24/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.7835 - accuracy: 0.7163 - val_loss: 0.9230 - val_accuracy: 0.6640
# Epoch 25/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.7539 - accuracy: 0.7311 - val_loss: 0.9413 - val_accuracy: 0.6620
# Epoch 26/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.7553 - accuracy: 0.7255 - val_loss: 0.8760 - val_accuracy: 0.6950
# Epoch 27/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.7170 - accuracy: 0.7412 - val_loss: 0.8329 - val_accuracy: 0.6910
# Epoch 28/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.6664 - accuracy: 0.7556 - val_loss: 0.8447 - val_accuracy: 0.7040
# Epoch 29/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.6424 - accuracy: 0.7644 - val_loss: 0.8865 - val_accuracy: 0.6910
# Epoch 30/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.6095 - accuracy: 0.7778 - val_loss: 0.8499 - val_accuracy: 0.7070
# Epoch 31/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.5705 - accuracy: 0.7904 - val_loss: 0.8641 - val_accuracy: 0.7000
# Epoch 32/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.5721 - accuracy: 0.7918 - val_loss: 0.8770 - val_accuracy: 0.7010
# Epoch 33/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.5366 - accuracy: 0.8069 - val_loss: 0.7827 - val_accuracy: 0.7230
# Epoch 34/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.5041 - accuracy: 0.8138 - val_loss: 0.8440 - val_accuracy: 0.7210
# Epoch 35/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.5038 - accuracy: 0.8171 - val_loss: 0.7874 - val_accuracy: 0.7190
# Epoch 36/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.4608 - accuracy: 0.8340 - val_loss: 0.8021 - val_accuracy: 0.7300
# Epoch 37/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.4377 - accuracy: 0.8443 - val_loss: 0.8294 - val_accuracy: 0.7190
# Epoch 38/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.4143 - accuracy: 0.8546 - val_loss: 0.7272 - val_accuracy: 0.7590
# Epoch 39/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.3994 - accuracy: 0.8528 - val_loss: 0.7647 - val_accuracy: 0.7440
# Epoch 40/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.3591 - accuracy: 0.8692 - val_loss: 0.7377 - val_accuracy: 0.7520
# Epoch 41/140
# 63/63 [==============================] - 20s 316ms/step - loss: 0.3457 - accuracy: 0.8727 - val_loss: 0.6816 - val_accuracy: 0.7850
# Epoch 42/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.3228 - accuracy: 0.8809 - val_loss: 0.7931 - val_accuracy: 0.7510
# Epoch 43/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.2980 - accuracy: 0.8923 - val_loss: 0.7622 - val_accuracy: 0.7510
# Epoch 44/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.2897 - accuracy: 0.8916 - val_loss: 0.7874 - val_accuracy: 0.7510
# Epoch 45/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.2840 - accuracy: 0.8979 - val_loss: 0.7016 - val_accuracy: 0.7660
# Epoch 46/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.2298 - accuracy: 0.9170 - val_loss: 0.7230 - val_accuracy: 0.7730
# Epoch 47/140
# 63/63 [==============================] - 20s 316ms/step - loss: 0.2608 - accuracy: 0.9081 - val_loss: 0.7354 - val_accuracy: 0.7810
# Epoch 48/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.2372 - accuracy: 0.9114 - val_loss: 0.8042 - val_accuracy: 0.7580
# Epoch 49/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.2146 - accuracy: 0.9265 - val_loss: 0.7757 - val_accuracy: 0.7730
# Epoch 50/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.2024 - accuracy: 0.9287 - val_loss: 0.6605 - val_accuracy: 0.7990
# Epoch 51/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1561 - accuracy: 0.9427 - val_loss: 0.7628 - val_accuracy: 0.7850
# Epoch 52/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.1787 - accuracy: 0.9364 - val_loss: 0.7765 - val_accuracy: 0.7770
# Epoch 53/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.2090 - accuracy: 0.9239 - val_loss: 0.8401 - val_accuracy: 0.7550
# Epoch 54/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1332 - accuracy: 0.9556 - val_loss: 0.7286 - val_accuracy: 0.8060
# Epoch 55/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1629 - accuracy: 0.9424 - val_loss: 1.0069 - val_accuracy: 0.7270
# Epoch 56/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1366 - accuracy: 0.9520 - val_loss: 0.7760 - val_accuracy: 0.7990
# Epoch 57/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.1276 - accuracy: 0.9564 - val_loss: 0.6889 - val_accuracy: 0.8210
# Epoch 58/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1112 - accuracy: 0.9629 - val_loss: 0.8812 - val_accuracy: 0.7820
# Epoch 59/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.1173 - accuracy: 0.9590 - val_loss: 0.7163 - val_accuracy: 0.8200
# Epoch 60/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0879 - accuracy: 0.9697 - val_loss: 0.8653 - val_accuracy: 0.7930
# Epoch 61/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1647 - accuracy: 0.9409 - val_loss: 0.9395 - val_accuracy: 0.7580
# Epoch 62/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1251 - accuracy: 0.9551 - val_loss: 0.7202 - val_accuracy: 0.8240
# Epoch 63/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1051 - accuracy: 0.9655 - val_loss: 0.8524 - val_accuracy: 0.7980
# Epoch 64/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0773 - accuracy: 0.9755 - val_loss: 0.7712 - val_accuracy: 0.8220
# Epoch 65/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0588 - accuracy: 0.9812 - val_loss: 0.8179 - val_accuracy: 0.8190
# Epoch 66/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0541 - accuracy: 0.9831 - val_loss: 0.8333 - val_accuracy: 0.8200
# Epoch 67/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0878 - accuracy: 0.9703 - val_loss: 0.8330 - val_accuracy: 0.8050
# Epoch 68/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0736 - accuracy: 0.9745 - val_loss: 0.9455 - val_accuracy: 0.7930
# Epoch 69/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0982 - accuracy: 0.9651 - val_loss: 0.8796 - val_accuracy: 0.8040
# Epoch 70/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0856 - accuracy: 0.9711 - val_loss: 0.8921 - val_accuracy: 0.8080
# Epoch 71/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0998 - accuracy: 0.9616 - val_loss: 0.9231 - val_accuracy: 0.8040
# Epoch 72/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.8468 - val_accuracy: 0.8280
# Epoch 73/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0754 - accuracy: 0.9744 - val_loss: 0.8549 - val_accuracy: 0.8060
# Epoch 74/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0660 - accuracy: 0.9781 - val_loss: 0.8745 - val_accuracy: 0.8040
# Epoch 75/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0327 - accuracy: 0.9894 - val_loss: 0.9274 - val_accuracy: 0.8150
# Epoch 76/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0661 - accuracy: 0.9765 - val_loss: 0.9812 - val_accuracy: 0.8080
# Epoch 77/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0510 - accuracy: 0.9822 - val_loss: 0.9461 - val_accuracy: 0.8140
# Epoch 78/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0529 - accuracy: 0.9812 - val_loss: 0.9800 - val_accuracy: 0.8170
# Epoch 79/140
# 63/63 [==============================] - 20s 317ms/step - loss: 0.0361 - accuracy: 0.9891 - val_loss: 0.9149 - val_accuracy: 0.8220
# Epoch 80/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 1.0461 - val_accuracy: 0.7960
# Epoch 81/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0668 - accuracy: 0.9756 - val_loss: 1.0044 - val_accuracy: 0.8140
# Epoch 82/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1209 - accuracy: 0.9582 - val_loss: 0.8769 - val_accuracy: 0.8120
# Epoch 83/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0615 - accuracy: 0.9797 - val_loss: 0.9915 - val_accuracy: 0.8200
# Epoch 84/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0678 - accuracy: 0.9754 - val_loss: 0.8824 - val_accuracy: 0.8120
# Epoch 85/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0279 - accuracy: 0.9929 - val_loss: 0.9270 - val_accuracy: 0.8410
# Epoch 86/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 1.0447 - val_accuracy: 0.8090
# Epoch 87/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.9628 - val_accuracy: 0.8300
# Epoch 88/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.0102 - accuracy: 0.9977 - val_loss: 0.9660 - val_accuracy: 0.8310
# Epoch 89/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0192 - accuracy: 0.9946 - val_loss: 1.0023 - val_accuracy: 0.8320
# Epoch 90/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0630 - accuracy: 0.9776 - val_loss: 1.1491 - val_accuracy: 0.7640
# Epoch 91/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.1421 - accuracy: 0.9506 - val_loss: 0.8694 - val_accuracy: 0.8140
# Epoch 92/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0417 - accuracy: 0.9879 - val_loss: 0.9310 - val_accuracy: 0.8110
# Epoch 93/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0223 - accuracy: 0.9936 - val_loss: 0.8784 - val_accuracy: 0.8380
# Epoch 94/140
# 63/63 [==============================] - 20s 317ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.9113 - val_accuracy: 0.8410
# Epoch 95/140
# 63/63 [==============================] - 21s 332ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.9307 - val_accuracy: 0.8410
# Epoch 96/140
# 63/63 [==============================] - 21s 330ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.9230 - val_accuracy: 0.8440
# Epoch 97/140
# 63/63 [==============================] - 21s 326ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.9075 - val_accuracy: 0.8500
# Epoch 98/140
# 63/63 [==============================] - 21s 331ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.9750 - val_accuracy: 0.8430
# Epoch 99/140
# 63/63 [==============================] - 21s 328ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.9742 - val_accuracy: 0.8460
# Epoch 100/140
# 63/63 [==============================] - 21s 327ms/step - loss: 0.0081 - accuracy: 0.9961 - val_loss: 1.0340 - val_accuracy: 0.8320
# Epoch 101/140
# 63/63 [==============================] - 21s 331ms/step - loss: 0.1407 - accuracy: 0.9565 - val_loss: 1.0558 - val_accuracy: 0.7650
# Epoch 102/140
# 63/63 [==============================] - 21s 326ms/step - loss: 0.1187 - accuracy: 0.9599 - val_loss: 0.9376 - val_accuracy: 0.7890
# Epoch 103/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.8764 - val_accuracy: 0.8230
# Epoch 104/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.8573 - val_accuracy: 0.8180
# Epoch 105/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0113 - accuracy: 0.9974 - val_loss: 0.9067 - val_accuracy: 0.8340
# Epoch 106/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.8765 - val_accuracy: 0.8450
# Epoch 107/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.8947 - val_accuracy: 0.8410
# Epoch 108/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.9075 - val_accuracy: 0.8440
# Epoch 109/140
# 63/63 [==============================] - 21s 326ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.9737 - val_accuracy: 0.8350
# Epoch 110/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.9438 - val_accuracy: 0.8360
# Epoch 111/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0167 - accuracy: 0.9942 - val_loss: 1.1707 - val_accuracy: 0.7890
# Epoch 112/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.1523 - accuracy: 0.9464 - val_loss: 0.9863 - val_accuracy: 0.7880
# Epoch 113/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0896 - accuracy: 0.9704 - val_loss: 0.8312 - val_accuracy: 0.8250
# Epoch 114/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0738 - accuracy: 0.9774 - val_loss: 0.8783 - val_accuracy: 0.8200
# Epoch 115/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0425 - accuracy: 0.9849 - val_loss: 0.9743 - val_accuracy: 0.8060
# Epoch 116/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0859 - accuracy: 0.9710 - val_loss: 0.9107 - val_accuracy: 0.8150
# Epoch 117/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0591 - accuracy: 0.9790 - val_loss: 0.8854 - val_accuracy: 0.8270
# Epoch 118/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 0.8719 - val_accuracy: 0.8450
# Epoch 119/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0204 - accuracy: 0.9942 - val_loss: 0.9347 - val_accuracy: 0.8200
# Epoch 120/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.9224 - val_accuracy: 0.8350
# Epoch 121/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.9189 - val_accuracy: 0.8380
# Epoch 122/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.9108 - val_accuracy: 0.8440
# Epoch 123/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.9445 - val_accuracy: 0.8370
# Epoch 124/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.9641 - val_accuracy: 0.8400
# Epoch 125/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 1.0877 - val_accuracy: 0.8110
# Epoch 126/140
# 63/63 [==============================] - 22s 349ms/step - loss: 0.1174 - accuracy: 0.9646 - val_loss: 1.1789 - val_accuracy: 0.7660
# Epoch 127/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.1460 - accuracy: 0.9524 - val_loss: 0.7951 - val_accuracy: 0.8200
# Epoch 128/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0386 - accuracy: 0.9879 - val_loss: 0.8357 - val_accuracy: 0.8280
# Epoch 129/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.0547 - accuracy: 0.9797 - val_loss: 0.9066 - val_accuracy: 0.8180
# Epoch 130/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 0.8768 - val_accuracy: 0.8410
# Epoch 131/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.8777 - val_accuracy: 0.8450
# Epoch 132/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.8733 - val_accuracy: 0.8510
# Epoch 133/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.8654 - val_accuracy: 0.8580
# Epoch 134/140
# 63/63 [==============================] - 20s 315ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.9168 - val_accuracy: 0.8450
# Epoch 135/140
# 63/63 [==============================] - 20s 316ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.9072 - val_accuracy: 0.8540
# Epoch 136/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.9206 - val_accuracy: 0.8470
# Epoch 137/140
# 63/63 [==============================] - 20s 312ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.9174 - val_accuracy: 0.8560
# Epoch 138/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.9123 - val_accuracy: 0.8610
# Epoch 139/140
# 63/63 [==============================] - 20s 313ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.9181 - val_accuracy: 0.8610
# Epoch 140/140
# 63/63 [==============================] - 20s 314ms/step - loss: 0.0017 - accuracy: 0.9989 - val_loss: 0.9421 - val_accuracy: 0.8610

# %%
if fresh_model:
    metrics = model_history.history
    plt.figure(figsize=(16,6))
    plt.subplot(1,2,1)
    plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
    plt.legend(['loss', 'val_loss'])
    plt.ylim([0, max(plt.ylim())])
    plt.xlabel('Epoch')
    plt.ylabel('Loss [CrossEntropy]')

    plt.subplot(1,2,2)
    plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
    plt.legend(['accuracy', 'val_accuracy'])
    plt.ylim([0, 100])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy [%]')
