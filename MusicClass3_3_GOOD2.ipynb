# %%
import tensorflow as tf
import numpy as np
import scipy
from scipy import misc
import glob
from PIL import Image
import os
import matplotlib.pyplot as plt
import librosa
from keras import layers
from keras.layers import (Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, 
                          Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D)
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
import pydot
from IPython.display import SVG, Audio
from keras.layers import Dropout
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from pydub import AudioSegment
import shutil
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
# Set the seed value for experiment reproducibility.
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification

genres = 'blues classical country disco hiphop jazz metal pop reggae rock'
genres = genres.split()

if not os.path.exists('content'):
  os.makedirs('content/')
  os.makedirs('content/spectrograms3sec_old')
  os.makedirs('content/spectrograms3sec_old/train')
  os.makedirs('content/spectrograms3sec_old/test')

  for g in genres:
    path_audio = os.path.join('content/audio3sec',f'{g}')
    os.makedirs(path_audio)
    path_train = os.path.join('content/spectrograms3sec_old/train',f'{g}')
    path_test = os.path.join('content/spectrograms3sec_old/test',f'{g}')
    os.makedirs(path_train)
    os.makedirs(path_test)

# %%
from pydub import AudioSegment
i = 0
for g in genres:
  if len(os.path.join('content/audio3sec/',f"{g}")) == 0:
    j=0
    print(f"{g}")
    for filename in os.listdir(os.path.join('data/genres',f"{g}")):
      song  =  os.path.join(f'data/genres/{g}',f'{filename}')
      j = j+1
      for w in range(0,10):
        i = i+1
        #print(i)
        t1 = 3*(w)*1000
        t2 = 3*(w+1)*1000
        newAudio = AudioSegment.from_wav(song)
        new = newAudio[t1:t2]
        new.export(f'content/audio3sec/{g}/{g+str(j)+str(w)}.wav', format="wav")

# %%
for g in genres:
  if len(os.path.join('content/spectrograms3sec_old/train/',f"{g}")) == 0:
    j = 0
    print(g)
    for filename in os.listdir(os.path.join('content/audio3sec',f"{g}")):
      song  =  os.path.join(f'content/audio3sec/{g}',f'{filename}')
      j = j+1
      
      y,sr = librosa.load(song,duration=3)
      #print(sr)
      mels = librosa.feature.melspectrogram(y=y,sr=sr)
      fig = plt.Figure()
      canvas = FigureCanvas(fig)
      p = plt.imshow(librosa.power_to_db(mels,ref=np.max))
      plt.savefig(f'content/spectrograms3sec_old/train/{g}/{g+str(j)}.png')

# %%
directory = "content/spectrograms3sec_old/train/"
for g in genres:
  if len(os.listdir(os.path.join('content/spectrograms3sec_old/test/',f"{g}"))) == 0:
    filenames = os.listdir(os.path.join(directory,f"{g}"))
    random.shuffle(filenames)
    test_files = filenames[0:100]

    for f in test_files:

      shutil.move(directory + f"{g}"+ "/" + f,"content/spectrograms3sec_old/test/" + f"{g}")

# %%
train_dir = "content/spectrograms3sec_old/train/"
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(288,432),color_mode="rgba",class_mode='categorical',batch_size=128)

validation_dir = "content/spectrograms3sec_old/test/"
vali_datagen = ImageDataGenerator(rescale=1./255)
vali_generator = vali_datagen.flow_from_directory(validation_dir,target_size=(288,432),color_mode='rgba',class_mode='categorical',batch_size=128)
# Out:
# Found 9000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
def GenreModel(input_shape = (288,432,4),classes=10):
  np.random.seed(10)
  X_input = Input(input_shape)

  X = Conv2D(8,kernel_size=(3,3),strides=(1,1),kernel_initializer = glorot_uniform(seed=10))(X_input)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(16,kernel_size=(3,3),strides = (1,1),kernel_initializer=glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)
  
  X = Conv2D(32,kernel_size=(3,3),strides = (1,1),kernel_initializer = glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  X = Conv2D(64,kernel_size=(3,3),strides=(1,1),kernel_initializer=glorot_uniform(seed=10))(X)
  X = BatchNormalization(axis=-1)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2,2))(X)

  
  X = Flatten()(X)

  X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=10))(X)

  model = Model(inputs=X_input,outputs=X,name='GenreModel')

  return model

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# checkpoint_path = "saved_cnn3/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# # Create a callback that saves the model's weights
# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                 save_weights_only=False,
#                                                 verbose=1)

model = GenreModel(input_shape=(288,432,4), classes=10)
opt = Adam(learning_rate=0.00005)
model.compile(optimizer = opt,loss='categorical_crossentropy',metrics=['accuracy',get_f1])
# Out:
# 2022-11-16 04:44:51.322148: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-16 04:44:51.323063: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.323253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.323378: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.622012: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.622134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.622232: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 04:44:51.622311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5735 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:0c:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "GenreModel"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 288, 432, 4)]     0
#
#  conv2d (Conv2D)             (None, 286, 430, 8)       296
#
#  batch_normalization (BatchN  (None, 286, 430, 8)      32
#  ormalization)
#
#  activation (Activation)     (None, 286, 430, 8)       0
#
#  max_pooling2d (MaxPooling2D  (None, 143, 215, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 141, 213, 16)      1168
#
#  batch_normalization_1 (Batc  (None, 141, 213, 16)     64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 141, 213, 16)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 106, 16)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 68, 104, 32)       4640
#
#  batch_normalization_2 (Batc  (None, 68, 104, 32)      128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 68, 104, 32)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 34, 52, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 50, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 32, 50, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 32, 50, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 25, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 25600)             0
#
#  fc10 (Dense)                (None, 10)                256010
#
# =================================================================
# Total params: 281,090
# Trainable params: 280,850
# Non-trainable params: 240
# _________________________________________________________________

# %%
if os.path.exists("saved/saved_cnn3_3"):
    model_history = model.load_model("saved/saved_cnn3_3")
else:
    model_history = model.fit_generator(train_generator,epochs=50,validation_data=vali_generator)
    model.save("saved/saved_cnn3_3")
# Out:
# /tmp/ipykernel_47719/1045722782.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_history = model.fit_generator(train_generator,epochs=50,validation_data=vali_generator)
# Epoch 1/50
# 2022-11-16 04:44:54.343094: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8200
# 2022-11-16 04:44:55.611555: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 70s 951ms/step - loss: 1.9041 - accuracy: 0.3158 - get_f1: 0.0902 - val_loss: 2.3115 - val_accuracy: 0.1010 - val_get_f1: 0.0000e+00
# Epoch 2/50
# 71/71 [==============================] - 67s 947ms/step - loss: 1.4398 - accuracy: 0.4863 - get_f1: 0.3022 - val_loss: 2.3087 - val_accuracy: 0.1670 - val_get_f1: 0.0000e+00
# Epoch 3/50
# 71/71 [==============================] - 67s 944ms/step - loss: 1.2632 - accuracy: 0.5546 - get_f1: 0.4275 - val_loss: 2.2937 - val_accuracy: 0.1710 - val_get_f1: 0.0019
# Epoch 4/50
# 71/71 [==============================] - 67s 938ms/step - loss: 1.1404 - accuracy: 0.6028 - get_f1: 0.5017 - val_loss: 1.9637 - val_accuracy: 0.2780 - val_get_f1: 0.1643
# Epoch 5/50
# 71/71 [==============================] - 67s 940ms/step - loss: 1.0461 - accuracy: 0.6401 - get_f1: 0.5621 - val_loss: 1.6181 - val_accuracy: 0.4200 - val_get_f1: 0.3103
# Epoch 6/50
# 71/71 [==============================] - 67s 952ms/step - loss: 0.9546 - accuracy: 0.6798 - get_f1: 0.6120 - val_loss: 1.3007 - val_accuracy: 0.5410 - val_get_f1: 0.4776
# Epoch 7/50
# 71/71 [==============================] - 67s 937ms/step - loss: 0.8994 - accuracy: 0.6960 - get_f1: 0.6437 - val_loss: 1.0879 - val_accuracy: 0.5970 - val_get_f1: 0.5737
# Epoch 8/50
# 71/71 [==============================] - 67s 941ms/step - loss: 0.8335 - accuracy: 0.7226 - get_f1: 0.6747 - val_loss: 1.0116 - val_accuracy: 0.6420 - val_get_f1: 0.6107
# Epoch 9/50
# 71/71 [==============================] - 66s 932ms/step - loss: 0.7757 - accuracy: 0.7531 - get_f1: 0.7077 - val_loss: 0.9307 - val_accuracy: 0.6830 - val_get_f1: 0.6379
# Epoch 10/50
# 71/71 [==============================] - 67s 951ms/step - loss: 0.7384 - accuracy: 0.7602 - get_f1: 0.7271 - val_loss: 0.9168 - val_accuracy: 0.6840 - val_get_f1: 0.6508
# Epoch 11/50
# 71/71 [==============================] - 67s 947ms/step - loss: 0.6959 - accuracy: 0.7774 - get_f1: 0.7460 - val_loss: 0.8952 - val_accuracy: 0.6890 - val_get_f1: 0.6655
# Epoch 12/50
# 71/71 [==============================] - 67s 945ms/step - loss: 0.6566 - accuracy: 0.7911 - get_f1: 0.7666 - val_loss: 0.8650 - val_accuracy: 0.7220 - val_get_f1: 0.6788
# Epoch 13/50
# 71/71 [==============================] - 66s 926ms/step - loss: 0.6142 - accuracy: 0.8103 - get_f1: 0.7872 - val_loss: 0.8288 - val_accuracy: 0.7190 - val_get_f1: 0.6953
# Epoch 14/50
# 71/71 [==============================] - 66s 928ms/step - loss: 0.5863 - accuracy: 0.8210 - get_f1: 0.8020 - val_loss: 0.8626 - val_accuracy: 0.7000 - val_get_f1: 0.6797
# Epoch 15/50
# 71/71 [==============================] - 67s 939ms/step - loss: 0.5478 - accuracy: 0.8349 - get_f1: 0.8165 - val_loss: 0.8075 - val_accuracy: 0.7050 - val_get_f1: 0.7043
# Epoch 16/50
# 71/71 [==============================] - 66s 927ms/step - loss: 0.5225 - accuracy: 0.8426 - get_f1: 0.8286 - val_loss: 0.7831 - val_accuracy: 0.7350 - val_get_f1: 0.7258
# Epoch 17/50
# 71/71 [==============================] - 68s 953ms/step - loss: 0.4936 - accuracy: 0.8568 - get_f1: 0.8385 - val_loss: 0.7649 - val_accuracy: 0.7240 - val_get_f1: 0.7164
# Epoch 18/50
# 71/71 [==============================] - 66s 929ms/step - loss: 0.4713 - accuracy: 0.8650 - get_f1: 0.8482 - val_loss: 0.7704 - val_accuracy: 0.7200 - val_get_f1: 0.7234
# Epoch 19/50
# 71/71 [==============================] - 67s 939ms/step - loss: 0.4433 - accuracy: 0.8740 - get_f1: 0.8591 - val_loss: 0.7889 - val_accuracy: 0.7190 - val_get_f1: 0.7064
# Epoch 20/50
# 71/71 [==============================] - 67s 942ms/step - loss: 0.4260 - accuracy: 0.8773 - get_f1: 0.8662 - val_loss: 0.7563 - val_accuracy: 0.7250 - val_get_f1: 0.7284
# Epoch 21/50
# 71/71 [==============================] - 67s 941ms/step - loss: 0.3979 - accuracy: 0.8899 - get_f1: 0.8813 - val_loss: 0.7477 - val_accuracy: 0.7510 - val_get_f1: 0.7227
# Epoch 22/50
# 71/71 [==============================] - 67s 941ms/step - loss: 0.3840 - accuracy: 0.8969 - get_f1: 0.8819 - val_loss: 0.7341 - val_accuracy: 0.7390 - val_get_f1: 0.7362
# Epoch 23/50
# 71/71 [==============================] - 67s 938ms/step - loss: 0.3535 - accuracy: 0.9053 - get_f1: 0.8985 - val_loss: 0.7378 - val_accuracy: 0.7410 - val_get_f1: 0.7323
# Epoch 24/50
# 71/71 [==============================] - 67s 937ms/step - loss: 0.3432 - accuracy: 0.9114 - get_f1: 0.9006 - val_loss: 0.7412 - val_accuracy: 0.7360 - val_get_f1: 0.7373
# Epoch 25/50
# 71/71 [==============================] - 67s 946ms/step - loss: 0.3299 - accuracy: 0.9162 - get_f1: 0.9071 - val_loss: 0.7222 - val_accuracy: 0.7520 - val_get_f1: 0.7420
# Epoch 26/50
# 71/71 [==============================] - 67s 946ms/step - loss: 0.3058 - accuracy: 0.9248 - get_f1: 0.9155 - val_loss: 0.7210 - val_accuracy: 0.7460 - val_get_f1: 0.7436
# Epoch 27/50
# 71/71 [==============================] - 66s 934ms/step - loss: 0.2899 - accuracy: 0.9316 - get_f1: 0.9259 - val_loss: 0.7109 - val_accuracy: 0.7590 - val_get_f1: 0.7504
# Epoch 28/50
# 71/71 [==============================] - 66s 928ms/step - loss: 0.2745 - accuracy: 0.9377 - get_f1: 0.9282 - val_loss: 0.7048 - val_accuracy: 0.7520 - val_get_f1: 0.7384
# Epoch 29/50
# 71/71 [==============================] - 67s 939ms/step - loss: 0.2635 - accuracy: 0.9397 - get_f1: 0.9320 - val_loss: 0.7059 - val_accuracy: 0.7620 - val_get_f1: 0.7520
# Epoch 30/50
# 71/71 [==============================] - 67s 942ms/step - loss: 0.2466 - accuracy: 0.9480 - get_f1: 0.9414 - val_loss: 0.7237 - val_accuracy: 0.7450 - val_get_f1: 0.7433
# Epoch 31/50
# 71/71 [==============================] - 67s 943ms/step - loss: 0.2324 - accuracy: 0.9547 - get_f1: 0.9482 - val_loss: 0.7158 - val_accuracy: 0.7560 - val_get_f1: 0.7444
# Epoch 32/50
# 71/71 [==============================] - 66s 926ms/step - loss: 0.2228 - accuracy: 0.9591 - get_f1: 0.9496 - val_loss: 0.7033 - val_accuracy: 0.7630 - val_get_f1: 0.7550
# Epoch 33/50
# 71/71 [==============================] - 66s 933ms/step - loss: 0.2099 - accuracy: 0.9634 - get_f1: 0.9550 - val_loss: 0.7008 - val_accuracy: 0.7580 - val_get_f1: 0.7515
# Epoch 34/50
# 71/71 [==============================] - 66s 931ms/step - loss: 0.1985 - accuracy: 0.9671 - get_f1: 0.9604 - val_loss: 0.6769 - val_accuracy: 0.7630 - val_get_f1: 0.7612
# Epoch 35/50
# 71/71 [==============================] - 67s 939ms/step - loss: 0.1885 - accuracy: 0.9702 - get_f1: 0.9641 - val_loss: 0.6838 - val_accuracy: 0.7600 - val_get_f1: 0.7610
# Epoch 36/50
# 71/71 [==============================] - 66s 934ms/step - loss: 0.1809 - accuracy: 0.9731 - get_f1: 0.9652 - val_loss: 0.6985 - val_accuracy: 0.7610 - val_get_f1: 0.7618
# Epoch 37/50
# 71/71 [==============================] - 67s 941ms/step - loss: 0.1680 - accuracy: 0.9787 - get_f1: 0.9728 - val_loss: 0.6788 - val_accuracy: 0.7720 - val_get_f1: 0.7645
# Epoch 38/50
# 71/71 [==============================] - 66s 936ms/step - loss: 0.1605 - accuracy: 0.9802 - get_f1: 0.9738 - val_loss: 0.6795 - val_accuracy: 0.7650 - val_get_f1: 0.7645
# Epoch 39/50
# 71/71 [==============================] - 66s 931ms/step - loss: 0.1531 - accuracy: 0.9809 - get_f1: 0.9766 - val_loss: 0.6658 - val_accuracy: 0.7740 - val_get_f1: 0.7678
# Epoch 40/50
# 71/71 [==============================] - 66s 928ms/step - loss: 0.1422 - accuracy: 0.9847 - get_f1: 0.9816 - val_loss: 0.6672 - val_accuracy: 0.7790 - val_get_f1: 0.7808
# Epoch 41/50
# 71/71 [==============================] - 67s 949ms/step - loss: 0.1365 - accuracy: 0.9848 - get_f1: 0.9817 - val_loss: 0.6865 - val_accuracy: 0.7590 - val_get_f1: 0.7547
# Epoch 42/50
# 71/71 [==============================] - 67s 950ms/step - loss: 0.1322 - accuracy: 0.9862 - get_f1: 0.9833 - val_loss: 0.6715 - val_accuracy: 0.7760 - val_get_f1: 0.7795
# Epoch 43/50
# 71/71 [==============================] - 66s 931ms/step - loss: 0.1227 - accuracy: 0.9903 - get_f1: 0.9864 - val_loss: 0.6722 - val_accuracy: 0.7760 - val_get_f1: 0.7675
# Epoch 44/50
# 71/71 [==============================] - 66s 933ms/step - loss: 0.1170 - accuracy: 0.9912 - get_f1: 0.9888 - val_loss: 0.6688 - val_accuracy: 0.7840 - val_get_f1: 0.7738
# Epoch 45/50
# 71/71 [==============================] - 66s 927ms/step - loss: 0.1090 - accuracy: 0.9922 - get_f1: 0.9901 - val_loss: 0.6607 - val_accuracy: 0.7830 - val_get_f1: 0.7753
# Epoch 46/50
# 71/71 [==============================] - 66s 930ms/step - loss: 0.1042 - accuracy: 0.9938 - get_f1: 0.9913 - val_loss: 0.6876 - val_accuracy: 0.7680 - val_get_f1: 0.7662
# Epoch 47/50
# 71/71 [==============================] - 67s 949ms/step - loss: 0.0985 - accuracy: 0.9948 - get_f1: 0.9930 - val_loss: 0.6547 - val_accuracy: 0.7870 - val_get_f1: 0.7767
# Epoch 48/50
# 71/71 [==============================] - 67s 942ms/step - loss: 0.0951 - accuracy: 0.9953 - get_f1: 0.9931 - val_loss: 0.6574 - val_accuracy: 0.7950 - val_get_f1: 0.7907
# Epoch 49/50
# 71/71 [==============================] - 67s 942ms/step - loss: 0.0910 - accuracy: 0.9956 - get_f1: 0.9937 - val_loss: 0.6602 - val_accuracy: 0.7890 - val_get_f1: 0.7919
# Epoch 50/50
# 71/71 [==============================] - 66s 929ms/step - loss: 0.0857 - accuracy: 0.9962 - get_f1: 0.9943 - val_loss: 0.6602 - val_accuracy: 0.7840 - val_get_f1: 0.7847
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved/saved_cnn3_3/assets
# INFO:tensorflow:Assets written to: saved/saved_cnn3_3/assets

# %%
metrics = model_history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(model_history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(model_history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
test_loss, test_acc, _ = model.evaluate(vali_generator, batch_size=128)
print("The test Loss is :", test_loss)
print("\nThe Best test Accuracy is :", test_acc*100)
# Out:
# 8/8 [==============================] - 7s 874ms/step - loss: 0.6602 - accuracy: 0.7840 - get_f1: 0.7837
# The test Loss is : 0.6602258086204529
#
# The Best test Accuracy is : 78.39999794960022

# %%
class estimator:
  _estimator_type = ''
  classes_=[]
  def __init__(self, model, classes):
    self.model = model
    self._estimator_type = 'classifier'
    self.classes_ = classes
  def predict(self, X):
    y_prob= self.model.predict(X)
    y_pred = y_prob.argmax(axis=1)
    return y_pred

classifier = estimator(model, genres)
figsize = (12,12)

x, y = zip(*(vali_generator[i] for i in range(len(vali_generator))))
x_val, y_val = np.vstack(x), np.vstack(y)
y_val = np.argmax(y_val, axis=1)

# %%
ConfusionMatrixDisplay.from_estimator(classifier, x_val, y_val, cmap='Blues', display_labels=genres ,normalize='true', ax=plt.subplots(figsize=figsize)[1])
# Out:
# 32/32 [==============================] - 1s 11ms/step

# %%
import pathlib
input_dir = pathlib.Path("input/")
audio_file_name = "chopin.wav"
sample_dir = "input/samples/"
audio_seg_dir = "input/audio_segments/"

predictions = []

if not input_dir.exists():
    os.mkdir("input")
    os.mkdir(sample_dir)
    os.mkdir(audio_seg_dir)

sample, sample_sr = librosa.load(os.path.join(sample_dir, audio_file_name))
sample_duration = int(librosa.get_duration(y=sample, sr=sample_sr))
Audio(sample, rate=sample_sr)

for i in range(int(sample_duration/3)): 
    t1 = i * 3 * 1000 #Works in milliseconds
    t2 = (i+1) * 3 * 1000
    newAudio = AudioSegment.from_wav(os.path.join(sample_dir, audio_file_name))
    newAudio = newAudio[t1:t2]
    newAudio.export(audio_seg_dir + 'audio_seg_' + str(i) +'.wav', format="wav") #Exports to a wav file in the current path.

from keras.utils import load_img, img_to_array

for af in os.listdir(audio_seg_dir):
    audio, sr = librosa.load(os.path.join(audio_seg_dir, af))
    mels = librosa.feature.melspectrogram(y=audio,sr=sr)
    fig = plt.Figure()
    canvas = FigureCanvas(fig)
    p = plt.imshow(librosa.power_to_db(mels,ref=np.max))

    spec_dir = "input/specs_segments"

    if not os.path.exists(spec_dir):
        os.mkdir(spec_dir)

    plt.savefig(os.path.join(spec_dir, af[:-3] + 'png'))

    image_data = load_img(os.path.join(spec_dir, af[:-3] + 'png'),color_mode='rgba',target_size=(288,432))
    image = img_to_array(image_data)
    image = np.reshape(image,(1,288,432,4))

    p = model.predict(image/255)
    p = p.reshape((10,))

    predictions.append(p)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step

# %%
avg_preds = [x / len(predictions) for x in np.array(predictions).sum(axis=0)]
predicted_label = np.argmax(avg_preds)

print("The Predicted Label was: " + genres[predicted_label])
# Out:
# The Predicted Label was: classical

# %%
plt.figure(figsize=(30,10))
plt.bar(genres, np.array(avg_preds))
plt.title("Inference Results")
plt.show()
